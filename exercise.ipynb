# %% [markdown]
# ## Exercises in Loading, Manipulating, and Saving JSON Data in Python and Pandas ##
#
# What we are going to do:
# - Load a CSV file with data of over 750 **wine reviews** into our notebook.
# - Use a distinct field to retrieve specific data, such as:
#     - Wine Score
#     - Red wine or White wine?
#     - Region
# - Look at using basic python to do this, then Pandas.
# - Save the resulting data to a JSON file.
#
# This exercise is part of the Coursera course: [Python, Bash and SQL Essentials for Data Engineering Specialization](https://www.coursera.org/specializations/python-bash-sql-data-engineering-duke)

# %% [markdown]
# ### My Tasks ###
# Fork the Github repository [alfredodeza/mapping-data](https://github.com/alfredodeza/mapping-data) and use the `exercise.ipynb` Jupyter Notebook that has pre-loaded starting points.
#
# The Jupyter Notebook has already preloaded the CSV file with examples on how to use it with Pandas or a Dictionary with the csv module.
#
# 1. Use a distinct field to retrieve data, like:
#
# - Type of wine (red or white)
#
# - Wine score range or baseline (e.g. between 90 and 92 points)
#
# - Region
#
# 2. Capture every row that matches your condition, and after processing, save everything to a formatted new JSON file

# %% [markdown]
# ## Practice your skills loading data from a CSV file ##
# In this exercise, you will load a CSV file and you'll perform some operations on it to extract data. If you know how to do this with the Pandas library, you can use that. If not, you can use the csv library with the ready-to-use example this notebook provides.

# %%
from csv import DictReader

# Open the CSV file and read it into a list of dictionaries and ignore unicode errors

with open('sample_data/wine-ratings-small.csv', encoding='utf-8', errors='ignore') as f:
    reader = DictReader(f)
    wines = list(reader)


# The wines variable is now a list of dictionaries, one for each row in the CSV file. This is the sample output of a single entry:
# {'': '1',
#  'name': 'Laurenz V Charming Gruner Veltliner 2014',
#  'grape': '',
#  'region': 'Kamptal, Austria',
#  'variety': 'White Wine',
#  'rating': '90.0',
#  'notes': ''}

# %% [markdown]
# Looping over the list of dictionaries can be tricky with plain Python. Specialized libraries like Pandas make this much easier but the downside is that you need to learn a new library. The following code is a bit more verbose but it's a good exercise to learn how to work with dictionaries in Python.

# %%
# This example creates a new list that only has wines from Napa Valley. The new list is called napa_wines:
napa_wines = []
for wine in wines:
    if 'Napa' in wine['region']:
        napa_wines.append(wine)

napa_wines
# Out:
# [{'': '24',
#   'name': 'Lava Vine Winery Napa Valley Cabernet Sauvignon 2014',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': 'A wonderful representation of how amazing the 2014 vintage could be and how to balance Napa Valley’s Intensity. A ripe cherry and cassis entry with dusted cocoa and a touch of graham cracker entice. The silky rich entry is so balanced there seems to be no separation from mid-palate through the lengthy finish with multitudes of fruit and spice to accompany. This Cabernet Sauvignon is fully integrated, super complex and will age beautifully.'},
#  {'': '25',
#   'name': 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2012',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Black berries and hints of strawberry invite with muddled cherry cola spices. Deep earthy tones on a silk entry proceed to a rich, full mid-palate. Expressive tannins make for a beautiful finish.'},
#  {'': '26',
#   'name': 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2013',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'A slight minty nose with dark chocolate and fresh blueberry captivate the senses. Notes of a baking spice dance on the pallet before giving way to rich, dark, and earthy finish. This extremely balanced gem will continue to show plenty of structure and integrity for years to come. Enjoy!'},
#  {'': '288',
#   'name': 'Leaping Lizard Cabernet Sauvignon 2007',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '90.0',
#   'notes': 'Our Cabernet Sauvignon is a full-bodied, fruit-forward wine that shows great structure with balanced acidity. Cassis, plum and crushed berry aromas are layered with a slight perfume/floral note and a hint of spicy oak. Red fruit flavors are found on the mid-palate through to the lingering finish. This wine is aged for\xa018 months \xa0in a mix of old and new oak barrels giving the wine a velvety finish with fine-grain tannins and a soft mouthfeel.'},
#  {'': '685',
#   'name': 'Levendi Stagecoach Cabernet Sauvignon 2008',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'From the Stagecoach Vineyard high on the eastern volcanic ridge above Napa, comes this rich and decadent, limited production Cabernet Sauvignon. The vivid red soils and rocky slopes come together to produce a wine with an aroma of sweet blackberry and cassis fruit that carries over into a superbly balanced and polished palate. '},
#  {'': '686',
#   'name': 'Levendi Sweeney Ranch Chardonnay 2010',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '93.0',
#   'notes': 'Beautifully ripe apple with a hint of caramel and oak spice, filled in with lemon chiffon notes. Caramelized apple and lemon vanilla cream flavors on the palate, with the texture gracefully balanced between a rich center and a crisp finish.'},
#  {'': '692',
#   'name': 'Levy & McClellan Proprietary Red 2004',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Full-bodied yet beautifully silky and seductive, it has shed most of its tannins, resulting in a complex, singular red wine of majestic proportions.'},
#  {'': '693',
#   'name': 'Levy & McClellan Proprietary Red 2005',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Uncompromising viticultural practices andmeticulously detailed vinification rewarded us with a wine ofgreat concentration and ripeness. The round supple tanninsin the 2005 Levy & McClellan are the result of thecool growing conditions and the extended ripening. As the wine develops, the expression of the site where it is grown continues to come to the forefront. Accentuated by the low yield in a year known for more generosity, combined with26 months in barrel, the result is a profoundly concentrated, supple and full-bodied wine.'},
#  {'': '694',
#   'name': 'Lewelling Cabernet Sauvignon 2000',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '90.0',
#   'notes': 'Medium-red color. Dark, Bordeaux-like aromas of currant and cedar, medium-full body, bright red currant and ripe cherry-like fruit on the palate, notes of cocoa and roasted coffee, very lively on the palate, a touch of oak (but not sweet) and cedar. Nice balance and shows exceptional length. This is not a fruit bomb--it has the real depth and class that many wines at twice the price wish they had. Should pair well with any veal or beef dish, lamb, pork loin or chops, and chicken dishes made with  mushrooms. Pretty good with medium-strong cheeses, too.  '},
#  {'': '695',
#   'name': 'Lewelling Cabernet Sauvignon 2005',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'A bright bouquet of wild black raspberry, dark plum, and Rainier cherry joined by vanilla, sweet tobacco and new saddle leather. A lively blend of blackberry, jammy raspberry and black currant fruit mingled with black pepper and baking spice, reinforced by assertive yet balanced sweet tannins and refreshing acidity.'},
#  {'': '696',
#   'name': 'Lewelling Cabernet Sauvignon 2001',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Intense black cherry, plum, and berry aromas intermingled with notes of anise, pain grille, and cedar. Rich cherry, red plum and raspberry flavors; white pepper, tobacco, and allspice; full-bodied with sweet, chewy tannins, balanced ripeness and fresh acidity.'},
#  {'': '697',
#   'name': 'Lewelling Cabernet Sauvignon 2006',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'An enticing mix of sweet black cherry, chocolate, and tobacco aromas. A blend of bramble berry and black cherry fruit mixed with exotic spice, earth, and tobacco flavors, backed by substantial, velvety tannins, marvelous texture and a lengthy finish. '},
#  {'': '698',
#   'name': 'Lewelling Cabernet Sauvignon 2007',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Intense black cherry, plum, and berry aromas intermingled with notes of anise, pain grille, and cedar. Rich cherry, red plum and raspberry flavors; white pepper, tobacco, and allspice; full-bodied with sweet, chewy tannins, balanced ripeness and fresh acidity.'},
#  {'': '699',
#   'name': 'Lewelling Cabernet Sauvignon 2009',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Red cherry, plum and brambleberry aromas with hints of cedar and chocolate. Vibrant blackberry, plum and tart cherry fruit intermingled with allspice, white pepper and vanilla on the palate with polished tannins and a long finish.'},
#  {'': '700',
#   'name': 'Lewelling Cabernet Sauvignon 2010',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'An enticing mix of sweet black cherry, currant, dark cocoa, and toasty oak aromas. A blend of blackberry and black cherry fruit mixed with cassis, mineral, espresso and tobacco flavors; round, chewy tannins, marvellous texture and a lengthy finish.'},
#  {'': '701',
#   'name': 'Lewelling Cabernet Sauvignon 2012',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Aromas of Bing cherry, currant and blackberry fruit, cocoa, vanilla, and baking spices. Intense blackberry, cassis, plum, and cherry flavors;coffee, anise and mineral; full-bodied, with fresh acidity,sweet, silky tannins and a rich mouth-feel.'},
#  {'': '702',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2003',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'The bouquet is blackberry, black currant, roasted coffee, vanilla and exotic spice aromas.  The flavor is rich black cherry and currant, licorice, mineral and expresso flavors; superb body and complexity coupled with balanced ripeness and fresh acidity; polished but firm tannins, layered richness and a long finish.'},
#  {'': '703',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2005',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'Bouquet: opulent aromas of black currant, blackberry, cherry, vanilla, and sweet toasty oak with a hint of anise.'},
#  {'': '704',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2006',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'Sumptuous aromas of rich dark berries, vanilla, and sweet smoke Flavors are sweet black cherry and blackberry flavors mingled with tobacco, mineral and wood smoke; bold, substantial tannins, mouthfilling richness, layered complexity, and a strong finish. '},
#  {'': '705',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2009',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Bouquet of enticing raspberry, cassis, and red plum aromas mixed with notes of chocolate and toasty oak. Flavors are rich blueberry, Bing cherry, and red raspberry flavors are also mingled with woodsmoke, earth, and spice; mouthfilling, velvety tannins and a complex, lingering finish.'},
#  {'': '706',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2008',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '98.0',
#   'notes': 'Sumptuous aromas of blackberry, cassis, Bing cherry and spice mixed with highlights of tobacco, cedar, vanilla and anise. Concentrated black plum, black cherry, and cassis flavors; allspice, dark cocoa, juniper and sweet smoke; exceptional depth and complexity; multi-layered richness; mouthfilling, velvety tannins and a lingering finish.'},
#  {'': '707',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2007',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '98.0',
#   'notes': 'An enticing mix of black fruit, tobacco and toasty oak aromas mingled with highlights of vanilla, cedar and licorice.  Concentrated black cherry, cassis, blueberry pie and espresso flavors; sweet smoke, anise and cedar; mouth-filling complexity and layered richness; dense but polished tannins and a very long finish.'},
#  {'': '708',
#   'name': 'Lewelling Wight Vineyard Cabernet Sauvignon 2010',
#   'grape': '',
#   'region': 'St. Helena, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'Sumptuous aromas of rich dark berries, cassis, vanilla, and sweet smoke. Bing cherry, blackcurrant and blackberry flavors mingled with spice box, mineral and dark cocoa; velvety tannins, mouthfilling richness, layered complexity, and a lingering finish.'},
#  {'': '709',
#   'name': "Lewis Cellars Alec's Blend Red 2002",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '96.0',
#   'notes': 'Number 12 on'},
#  {'': '710',
#   'name': "Lewis Cellars Alec's Blend Red 2003",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': "The formula for the 2002 Alec's Blend was so successful the winery again combined 60% Syrah, 30% Merlot, and 10% Cabernet Sauvignon to create this delicious wine, named after Dennis' first son. The wine is loaded with seductive oak spice, candle wax, and ripe black fruit. Hedonistic, rich, and complex, the wine has great mouth-feel with balance, depth, and a long, lingering finish."},
#  {'': '711',
#   'name': "Lewis Cellars Alec's Blend Red 2007",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': "These days drifting the rear wheel of his 4-stroke bike on a dirt oval is Alec's idea of fun, while his 2007 vintage wine is a straight-line sprint to pleasure. 70% Syrah, 20% Cabernet Sauvignon and 10% Merlot, this is one sweet ride, loaded with wild blackberries and laced with mocha, cola, and vanilla oak spice. Super-smooth, plush and round, there's plenty of throttle too, with chocolaty tannins and just enough grip to keep the fun serious. 1,400 cases produced."},
#  {'': '712',
#   'name': "Lewis Cellars Alec's Blend Red 2009",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': "With Alec already starting high school it's feeling like life in the fast lane. Top Gear is actually his favorite TV show and this new blend of 80% Syrah, 17% Merlot and 3% Cabernet Sauvignon packs plenty of power and youthful pleasure. Sappy black cherry and blueberry fruits are injected with clove and vanilla oak spice plus traces of truffle and sandalwood. Lively off the line, the palate performs with all the complex componentry and smooth power of a 4-valve, liquid-cooled 4-stroke engine."},
#  {'': '713',
#   'name': "Lewis Cellars Alec's Blend Red 2005",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Everyone agrees that Alec is one sweet kid, and his blend from the 2005 vintage is the wine equivalent of "wild mountain blackberry" –a favorite flavor ice cream from childhood. 70% Syrah and 30% Cabernet Sauvignon, the wine is opulent, ripe and seductive with cedar-laced oak spice aromas, coffee shadings and scoopfuls of juicy black fruit. The plush palate packs a chocolate truffle surprise with great length and soft, chewy tannins.'},
#  {'': '714',
#   'name': "Lewis Cellars Alec's Blend Red 2010",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': "All-mountain is Alec's favorite kind of cycling and it best describes this deliciously complex blend.  Heading up trail, the air is heavy with wild blueberry, violets, and oak forest aromas.  Dropping into descent, deep chutes of blue-black fruit consume a full 160mm of fork travel.  Picking up speed the palate turns lively and technical with youthful acidity and some tight twists through the trees.  Mocha and espresso bean flavors kick in just as you glide through the dust to a fine chocolaty finish. "},
#  {'': '715',
#   'name': "Lewis Cellars Alec's Blend Red 2014",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': "With one year of college completed, Alec's wine is both boy and man in this boundary-pushing blend of Syrah 60%, Merlot 34% and Cabernet 6%. Asserting his independence through explosively ripe blackberry and huckleberry fruits, there's also kirsch-like cherry cola, spicy oak, supple tannin and a trace of s'mores that's closer to home. Tremendously youthful and seriously good fun, Alec's Blend remains a kid at heart."},
#  {'': '716',
#   'name': "Lewis Cellars Alec's Blend Red 2013",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'A blend of 60% Syrah, 22% Merlot and 18% Cabernet Sauvignon - a power trio of guitar, bass and drums that rocks harder than any vintage in recent memory. Super ripe blackberry, vanilla blueberry, mocha and oak spices gain presence and steadily push the volume past 10. Tons of ripe, hedonistic fruit brings big stage presence while handsomely hewn tannins add drive and keep this wall of sound distortion free.'},
#  {'': '717',
#   'name': "Lewis Cellars Alec's Blend Red 2017",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Complex and fruit-forward with opulent black cherry and a dash of sweet molasses. Sporting plush palate texture throughout, the wine finishes with delicious chocolatey tannins. '},
#  {'': '724',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2002',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '96.0',
#   'notes': 'Showcasing the unique personalities of small hillside vineyards from Pritchard Hill, Oakville and Rutherford, the 2002 Napa Valley Cabernet delivers compelling aromas of mocha, ripe berries, tobacco and sweet oak spice. The wine is 100% Cabernet Sauvignon, complex, rich and focused. With a deep core of black fruit and traces of briar and vanilla, it turns chocolaty and long on the palate with serious, integrated tannins.'},
#  {'': '725',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2004',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Showcasing the unique personalities of small hillside vineyards from Pritchard Hill, Rutherford, and Calistoga our 2004 Napa Valley Cabernet delivers compelling aromas of black currant, mocha and sweet oak spice. 100% Cabernet Sauvignon, the wine is complex, rich and focused. Built around a core of concentrated fruit, it serves up sumptuous, round, mouth-feel with traces of tobacco and briar. Beautifully structured, the wine develops distinctive chocolate flavors that travel long on the finish with finely integrated tannins.'},
#  {'': '726',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2005',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': 'Showcasing the unique personalities of small hillside vineyards from Pritchard Hill, Rutherford, and Calistoga our 2005 Napa Valley Cabernet delivers complex aromas of black currant, sweet oak spice, espresso and tobacco. 100% Cabernet Sauvignon, the wine makes a sweeping broad entry with briary, black fruit at the core and compelling chocolate flavors that yield to a long chewy finish.'},
#  {'': '727',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2012',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': "The 2012 ranks among Lewis Cellars' best bottlings of Napa Cabernet. Enticing, deep-fruited aromas of black currant, berry and chocolate are stippled with cedar, clove and cinnamon oak spices. The palate centers on opulent core fruit that swirls around a defined structure of supple tannins. With complex undertones of truffle, black pepper and briar, this interplay finally winds down to a long chocolaty finish."},
#  {'': '728',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2015',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Like an Aston Martin V-12 the 2015 Napa Valley Cabernet is a silky powerhouse of fruit at wide-open-throttle. Black currant, plum and juicy ripe berries rev freely on the palate with seductive oak spice, candle wax and semi-sweet chocolate aromas. Fine-tuned and polished, the wine is deceptively powerful with supple, sweeping tannins.'},
#  {'': '729',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2014',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': "Our 2014 Napa Valley Cab takes center stage in a flashy jumpsuit with super plush fruit and sexy oak spices - Elvis is in the house! There's a whole lotta fruit going on, playing out in perfect pitch and velvety voice - it's irresistibly good. Classic, three-chord composition provides structure with notes of cedar, clove and sweet tobacco for added melody. Finely polished with chocolaty tannins, something like blue suede shoes."},
#  {'': '730',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2013',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': '#1'},
#  {'': '731',
#   'name': 'Lewis Cellars Cabernet Sauvignon 2017',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Dense, layered aromas with sweet cocoa, alluring oak spice and wow-factor frontal fruit, the wine is showy yet seriously structured. Creamy melted berry character gives way to supple muscle with integrated tannins and a long, lavish finish.'},
#  {'': '732',
#   'name': 'Lewis Cellars Cuvee L 2005',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Think of Cuvee L as super-charged Lewis Reserve Cabernet. Red wine at red-line. First created from the spectacular 1997 vintage, the single best barrels from our finest lots fuel this rare wine. Cuvee L is not produced every year. It is only blended when we have the components to create a wine of greater intensity, depth and distinction than our Reserve Cabernet. '},
#  {'': '733',
#   'name': 'Lewis Cellars Cuvee L 2006',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'First created from the spectacular 1997 vintage, the single best barrels from our finest lots fuel this rare wine. Think of Cuvee L as super-charged Lewis Reserve Cabernet. Cuvee L is not produced every year. It is only blended when we have the components to create a wine of greater intensity, depth and distinction than our Reserve Cabernet. '},
#  {'': '734',
#   'name': 'Lewis Cellars Cuvee L Cabernet Sauvignon 2014',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Our 2014 Cuvee L carries a cargo of fruit more laden than a Spanish galleon. Awash with crushed berries, clove and black truffle the wine superbly melds redolent ripe fruit with sweet oak spices. Broad and round on entry, this 100% Cabernet Sauvignon swells at mid-palate and packs a plush yet potent finish like a chocolate-coated cannonball.'},
#  {'': '735',
#   'name': 'Lewis Cellars Cuvee L Cabernet Sauvignon 2015',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '96.0',
#   'notes': 'Straight from James Fenimore Cooper’s novel, Last of the Mohicans, comes our 2015 Cuvee L – a noble savage from an outstanding vintage with great depth of character. 100% Cabernet Sauvignon with the strength of a grizzly and the soul of a chief this onyx and indigo wine is cloaked in tiers of blackberry with a quiver of clove and cedary oak spices. Broad paths of richly rendered fruit trail into hand-hewn tannins reflecting nature’s winding ways.'},
#  {'': '736',
#   'name': 'Lewis Cellars Hillstone Vineyard Cabernet Sauvignon 2014',
#   'grape': '',
#   'region': 'Rutherford, Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'This gorgeous wine, equal parts show-house and rustic cabin, sits along an alpine lake deep with black currants and massive ripe fruit. The air is redolent, with blackberry, clove, candle wax and vanilla oak spices. Picking up weight and muscle below the surface, the wine is anchored in fine tannins.'},
#  {'': '737',
#   'name': 'Lewis Cellars Hudson Vineyards Syrah 2006',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': 'The relatively cool 2006 harvest enhanced the inherent Rhone character of our Hudson Vineyards Syrah from these famously farmed vines in Napa Carneros. Finely woven and complex this 100% Syrah from a single small block serves up a potpourri of red/black fruits, white pepper, herbes de Provence, and allspice. Black raspberry fruit flavors are framed in toasty oak and brought to fine focus. '},
#  {'': '738',
#   'name': "Lewis Cellars Mason's Cabernet Sauvignon 2003",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': "In keeping with family tradition, this bottling celebrates the birth of Dennis' third son, Mason, in January 2003. Mason's wine is 100% Cabernet Sauvignon sourced from a single vineyard on a sunny ridge high on Mt. Veeder, farmed by Napa Valley legend, David Abreu. The wine is plush and spicy with ripe, forward fruit and soft, round tannins, brimming with wild berries, toasty oak and shadings of briar and tobacco."},
#  {'': '739',
#   'name': "Lewis Cellars Mason's Cabernet Sauvignon 2015",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': "Mason has been going to CrossFit and it shows. No whiskers yet but his 2015 vintage has more serious character, complexity and muscle than ever. Redolent with deeply ripened berries, baker's chocolate, cola, and cedary oak spice the wine is concentrated and rich on entry. Picking up notes of café latte toward the finish, a network of sinewy yet supple tannins provides a platform for this bulked up wine. "},
#  {'': '740',
#   'name': "Lewis Cellars Mason's Cabernet Sauvignon 2018",
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'Sporting some Senior-year swagger, the 2018 Mason’s Cabernet is front-loaded with black plum, cherry, chocolate and cedary spice.  Sourced from several of the same vineyards as our Napa Cabernet this wine is boldly fruited yet youthful with tons of juicy character and a deliciously fresh finish.'},
#  {'': '741',
#   'name': 'Lewis Cellars Merlot 2000',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': 'Bursting with black plum and sweet cedar our Merlot is opulent and delicious, rivaling any of our Merlot bottlings to date. These low-yielding vines from Oakville, Oak Knoll and Pritchard Hill have produced a wine that is smooth, yet thickly textured, jammy yet serious.'},
#  {'': '742',
#   'name': 'Lewis Cellars Napa Valley Chardonnay 2008',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '91.0',
#   'notes': 'Crafted from a combination of Oak Knoll vines and longer-hanging Carneros clusters, our 2008 Napa Valley Chardonnay is satisfyingly ripe, yet focused and fresh in the same sip. Showy stone fruit, pear, hazelnut and toasty oak spices spill from the glass. Rich-bodied, fruitful and round on the palate with vanilla and subtle minerality, the wine is threaded with lively acidity bringing length and focus to a fine finish.'},
#  {'': '743',
#   'name': 'Lewis Cellars Napa Valley Chardonnay 2015',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '92.0',
#   'notes': 'Grapes for the 2015 Napa Chardonnay came in early and the wine centers around ripe Bosc pear and Fuji apple with delicious caramel custard, pie crust and hazelnut. Thickly textured and satiny smooth like Deux-Sevres butter, the richness and weight are buttressed with native acidity and subtle minerality bringing complexity and length to this delicious wine.'},
#  {'': '744',
#   'name': 'Lewis Cellars Napa Valley Chardonnay 2014',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '95.0',
#   'notes': 'Another warm vintage and generous crop brought plenty of sun-kissed fruit for our 2014 Napa Valley Chardonnay. Ripened red and green pears with white peach are threaded with tantalizing cinnamon, nutmeg and caramel spices. The cream-textured palate is opulent, full-bodied and delicious with notes of vanilla, mineral and flaky croissant that carry into a long and increasingly focused finish. '},
#  {'': '745',
#   'name': 'Lewis Cellars Napa Valley Chardonnay 2016',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '92.0',
#   'notes': 'Golden delicious apple, honeysuckle blossom and toasty caramel spice aromas are served up generously in the 2016 Napa Chardonnay. Silky in texture with ripe tree fruit and plenty of drive the wine is athletic and complex with a tail of smoky mineral and lees character.'},
#  {'': '746',
#   'name': 'Lewis Cellars Napa Valley Syrah 2006',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Crafted from hillside blocks in low-vigor volcanic soils at 1,500 feet, this 100% Syrah shows a taut, restrained character before erupting loads of oaky sweet spice, vanilla and cocoa aromas. At its core, the 2006 Syrah is dense and deeply fruited with ripe blueberry and brooding black fruit, thick with fleshy texture and firm tannins.'},
#  {'': '747',
#   'name': 'Lewis Cellars Napa Valley Syrah 2007',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': "Our 2007 Syrah Napa Valley is the muscle car, the big-block powered bottle from our Rhone wine line-up. Mountain vines in low-vigor volcanic soils at 1,500 feet yield high-octane juice that's practically jet-black and packed with cedary oak spice and smoky dark fruit. Brambly, lifted and dense, the wine is also vibrant and fresh, framed with chewy, long-throw tannins that travel far down the road."},
#  {'': '748',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2011',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Scarce in quantity the 2011 Reserve Cabernet delivers plenty of complex aromas and lots of classic character. Sourced from a small collection of hillside and benchland vineyards in Calistoga, Oak Knoll and Rutherford, the wine centers around ripe currant and blue-black fruits threaded with tobacco leaf, nutmeg, baking spices and sweet toasty oak. Elegant and supple at first sip the wine gains focus, finishing with fine structure.'},
#  {'': '749',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2016',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'This Cabernet is a silky powerhouse of fruit at wide-open-throttle. Black currant, plum and juicy ripe berries rev freely on the palate with seductive oak spice, candle wax and semi-sweet chocolate aromas. Fine-tuned and polished, the wine is deceptively powerful with supple, sweeping tannins.'},
#  {'': '750',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon (1.5L Magnum) 2004',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': "This 2004 bottling could be Lewis Cellars' most captivating Reserve Cabernet Sauvignon yet. It combines the breadth and power of vintages like ’97 and ’01, with the depth and rich fruit of the ’02 vintage. Crafted from Pritchard Hill, Calistoga, Rutherford and Oak Knoll hillside vineyards and blended with 8% Cabernet Franc, the nose is a powder keg of explosive black fruit and blueberries with seamlessly fused oak spices, cedar, cocoa and espresso. The palate is a cannonball of concentrated core fruit with delicious, chewy texture and rich, round mouthfeel that travels leagues on sinewy tannins."},
#  {'': '751',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 1995',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '90.0',
#   'notes': 'The nose is powerful with cedar, oak and blackberry aromas. The palate is muscular, densely layered with black fruit and dark chocolate flavors, integrated with full round tannins. Delicious now, this wine will continue to improve with bottle age.'},
#  {'': '752',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2000',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '91.0',
#   'notes': 'Our 2000 Reserve Cabernet is a beautiful, showy wine, spilling-over with spicy oak and aromatic cedar, centered on opulent black fruit. Absolutely rich, ripe and round, we used 90% Cabernet Sauvignon, 7% Cabernet Franc and 3% Merlot in this Reserve blend. A cloak of vanilla, clove and seductive oak spice wraps around a deeply fruited core of currant and wild berries with hints of anise and chocolate that gradually give way to long, mouth-coating tannins. 2,300 cases produced. '},
#  {'': '753',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2005',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Our 2005 Reserve Cabernet Sauvignon is a broad-shouldered blend of 93% Cabernet and 7% Cabernet Franc, crafted from Pritchard Hill, Calistoga, Rutherford and Oak Knoll hillside vineyards. The nose is saturated with blackberry and sweet oak spice, tinged with toffee and chocolate. On entry the wine is brooding, tightly packed with fleshy fruit and sinewy texture that gathers richness and length on the palate with satisfying, fine-grained tannins.'},
#  {'': '754',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2006',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'Seductive, sleek and serious best describe our 2006 Reserve Cabernet Sauvignon. 96% Cabernet and 4% Cabernet Franc, this opulent wine is crafted from Pritchard Hill, Calistoga, Rutherford and Oak Knoll hillside vineyards. Cedary sweet oak spice, black fruit and cocoa aromas are potent. On entry the wine is deeply fruited, plush and round with kirsch, café mocha and blackberry flavors supporting very supple, fine-grained tannins and delivering great texture and length.'},
#  {'': '755',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2007',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'From the exceptional 2007 vintage, with production down 15% from 2006, we have crafted a densely woven, deeply fruited Reserve Cabernet rooted in Pritchard Hill, Calistoga, Rutherford and Oak Knoll hillside vineyards. Broad-shouldered and muscular, this blend of 97% Cabernet Sauvignon and 3% Cabernet Franc is packed with black currants and berries, dark chocolate, espresso, and sweet cedar and oak spice. Thickly textured on a massive scale with saturated fruit and sinewy tannins, this wine will stand tall for many years. 1,700 cases produced.'},
#  {'': '756',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2008',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': 'Built for comfort as much as speed, the 2008 vintage is packed with fruit and ready to roll, reminding us of our outstanding 2002 Reserve Cabernet. Like the rich interior of a Ferrari GTB, the nose is showy, ripe and rustic with black currant, clove, tar and exotic oak spices. Under the hood this blend of 98% Cabernet Sauvignon and 2% Petit Verdot shows plenty of extract and fleshy fruit delivering seamless power and expansive mouth feel. Moderate, chocolaty tannins engage mid-palate to gradually tighten the chassis and bring a lively quality to the ride.'},
#  {'': '757',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2009',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '94.0',
#   'notes': "This elegant and opulently spiced 2009 Reserve Cabernet is sourced from a small collection of hillside and benchland vineyards rooted in the Oak Knoll and Calistoga appellations. Infused with exotic oak, cocoa and clove spices this blend of 98% Cabernet Sauvignon and 2% Petit Verdot is powerfully aromatic. Sweet black currant and boysenberry flavors gradually take the backseat to a more muscular mid-palate framed with sinewy tannins and baker's chocolate."},
#  {'': '758',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2010',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '96.0',
#   'notes': ''},
#  {'': '759',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2011',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'Scarce in quantity the 2011 Reserve Cabernet delivers plenty of complex aromas and lots of classic character. Sourced from a small collection of hillside and benchland vineyards in Calistoga, Oak Knoll and Rutherford, the wine centers around ripe currant and blue-black fruits threaded with tobacco leaf, nutmeg, baking spices and sweet toasty oak. Elegant and supple at first sip the wine gains focus, finishing with fine structure.'},
#  {'': '760',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2015',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'From the outstanding 2015 vintage the Reserve Cabernet is powerfully seductive, brilliant and black in hue with kirsch-like crushed berries and showy cedar spice. Ripe, hi-tone fruit aromas are laced with candlewax, clove and cocoa. Expansive, with tiers of black fruit and velvety texture, the palate builds depth and power culminating in a muscular, long finish with supple young tannins.'},
#  {'': '761',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2014',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '95.0',
#   'notes': 'The best qualities from our past two vintages come together like yin and yang in our singular 2014 Reserve Cabernet.  Radiant color and soaring aromas of ripe blackberry, toasty oak spices, black truffle and cappuccino make an impressive entrée.  Fleshy and supple at first, the wine expands into deeper, more concentrated fruit layers with chocolaty, fine-grained tannins.'},
#  {'': '762',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon 2016',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '93.0',
#   'notes': 'There is distinct power and complexity to our 2016 Reserve Cabernet. Navy blue-black yet brilliant in color the wine is front-loaded with ripe fruit of crushed currants and berries. Secondary notes bring mineral and earth aromas laced with sweet anise and oak spice. Packed with fruit on entry, a dusky, sinewy character develops on the palate with fine-grained tannins tailing to the finish.'},
#  {'': '763',
#   'name': 'Lewis Cellars Reserve Cabernet Sauvignon (scuffed labels) 2012',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '96.0',
#   'notes': 'The headline reads: "2012 Reserve Cabernet - Return of the Big Block". Running on high octane aromas and built on an iron block with deep reserves of black fruit this 100% Cabernet blend delivers 700 horsepower at the wheels. Coming off idle the nose slowly explodes with sappy dark and rustic berries, clove, cedar and sweet oak spices. Forged, ripe fruit pistons pump out the power for miles until finally finishing with an impressive band of ported and polished tannins. Motor must be warmed-up before driving!'},
#  {'': '764',
#   'name': 'Lewis Cellars Reserve Chardonnay 2008',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '93.0',
#   'notes': 'Bottled unfined and unfiltered in December last year, our 2008 Reserve Chardonnay shows fantastic focus, complexity and richness. There is great breadth and allure in the nose of crushed blossoms and stone, lime zest, hazelnut and pear; but the palate takes center stage. Like a French kiss, the wine is sumptuous and silky-rich in texture with creamy minerality and endlessly intriguing notes of bread crust and caramel. The palate retains great focus and structure throughout, as it leads to a long, luxurious finish.'},
#  {'': '765',
#   'name': 'Lewis Cellars Reserve Chardonnay 2015',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '92.0',
#   'notes': 'Neil Young\'s "Cinnamon Girl" best captures the character of our rocking 2015 Reserve Chardonnay. Ripe yet succulent D\'Anjou pear, gardenia blossom, sweet mineral spice and toasty brioche aromas come singing through. Broad-shouldered, with creamy textured leesy flavors, the wine reaches great depth while maintaining precision and serious structure.'},
#  {'': '766',
#   'name': 'Lewis Cellars Reserve Chardonnay 2018',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '93.0',
#   'notes': 'From the long growing season of 2018, this Napa Reserve Chardonnay has super showy aromatics, deliciously complex flavors and alluring texture that can’t be captured in words. Opening with white flower blossoms, green pear, lime zest and crushed stone mineral the wine is fragrant and long-limbed. Profoundly rich and silky texture is underpinned with structural detail and a stunningly long tail.'},
#  {'': '767',
#   'name': 'Lewis Cellars Reserve Chardonnay 2017',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '93.0',
#   'notes': 'Think of our 2017 Reserve Chardonnay as a Rolls Royce Wraith – offering a sumptuous interior with serious performance. A plethora of heady aromas alight from the glass with Anjou pear, warm brioche, sweet mineral spice and gardenia blossom. Lush yet lively with great depth and gauzy texture the wine shows impeccable build quality and attention to detail with a miles long finish.'},
#  {'': '768',
#   'name': 'Lewis Cellars Reserve Merlot 1995',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'Red Wine',
#   'rating': '92.0',
#   'notes': 'When asked to describe our Reserve Merlot as briefly as possible our response is "velvet hammer." Supple and velvety rich on the palate, layered with dark ripe fruit, the wine finishes polished and round.'},
#  {'': '769',
#   'name': 'Lewis Cellars Sauvignon Blanc 2016',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '90.0',
#   'notes': "The warm, vibrant character and seductive imagery of Paul Gauguin's Tahiti are captured in our 2016 Sauvignon Blanc. Awash in ripe mango, guava and papaya and laced with tropical blossoms, vanilla and spice, the wine is lush and luxuriant, fruitful to the core, yet draped in native acidity and a fleck of salinity that frame and lengthen the canvas."},
#  {'': '770',
#   'name': 'Lewis Cellars Sauvignon Blanc 2018',
#   'grape': '',
#   'region': 'Napa Valley, California',
#   'variety': 'White Wine',
#   'rating': '92.0',
#   'notes': 'Like a sailplane this 2018 Sauvignon Blanc soars with alluring floral spice, lemon-lime zest and hints of vanilla. A leading edge of native acidity frames a camber line of ripe mango and tropical fruit that tails gracefully with succulent lime skin and subtle mineral.'}]

# %% [markdown]
# **NOTE**: If you are trying to use ratings, remember that you will need to convert the ratings to integers for numerical comparisons.

# %% [markdown]
# ## My Response to the Tasks ##
#
# There's so much that we can do with Python's Pandas library for data manipulation. But, I'd like to explore some library-independent solutions to the tasks first. Then we will do it again with Pandas.
#
# **My Goals**
# 1. Work with filtering text
#     - Create a dictionary of white wines from the wine ratings csv.
#     - Save it as a new JSON file.
# 2. Work with filtering numbers
#     - Create a dictionary of wines ranked at 99 points.
#     - Save it as a new JSON file.
# 3. Once done with basic Python, do it again using the Pandas library.
# 4. I love wine! Explore the dataset and see if we can improve upon it.

# %%
# Let's build a dictionary of white wines by for-looping through the 'wines' dictionary
# and testing each index to see if the word 'White' appears in the 'variety' column. 
# If the condition of the if-test comes out True, the if-test will add (append) that
# row to our new 'white_wines' dictionary object.

import json

white_wines = []
for wine in wines:
    if 'White' in wine['variety']:
        white_wines.append(wine)

# We can use some properties of the json.dumps() function to make our JSON text pretty like 
# a fine white Burgundy. We can do things like sorting by index-keys, and automatically
# adding indentation. Remember, the json.dumps() function takes Python data, which is what is in 
# the the 'white_wines' variable that we get out of that for-loop above. Then in order to make it 
# the type of text-data that is expected of a JSON formatted file, we use json.dumps(). 
# Remember, Dumps TO String. (String, being text-format.) The string format is useful for working
# with the JSON when you aren't working with files, like sending/recieving from a network.

white_wine_json = json.dumps(white_wines, sort_keys=True, indent=4)
print(white_wine_json)

# But what if we need to save a file? We can use the `.dump()` JSON method 
# (note no 's'!) to save it to a new JSON file. We can use the same sorting
# and indentation properties that we used with .dumps, earlier. 

with open('sample_data/white_wines.json', 'w') as f:
   json.dump(white_wines, f, sort_keys=True, indent=4)

# Check the sample_data/ folder for your new white_wines.json file.
# Run the code again without the sort_keys and indent properties. 
# See how it's different.
# Out:
# [
#     {
#         "": "0",
#         "grape": "",
#         "name": "Laurenz V Charming Gruner Veltliner 2013",
#         "notes": "Aromas of ripe apples and a typical Veltliner spiciness marry to create a fascinating fruit bouquet. On the palate, the wine is soft and juicy, supported by a fine fruit acidity. Very harmonious, allowing for perfectly smooth drinking. Simply charming!",
#         "rating": "90.0",
#         "region": "Kamptal, Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "1",
#         "grape": "",
#         "name": "Laurenz V Charming Gruner Veltliner 2014",
#         "notes": "Aromas of ripe apples and a typical Veltliner spiciness marry to create a fascinating fruit bouquet. On the palate, the wine is soft and juicy, supported by a fine fruit acidity. Very harmonious, allowing for perfectly smooth drinking. Simply charming!",
#         "rating": "90.0",
#         "region": "Kamptal, Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "2",
#         "grape": "",
#         "name": "Laurenz V Singing Gruner Veltliner 2007",
#         "notes": "A very attractive fruit bouquet yields apple, peach and citrus aromas along with a typical Veltliner spiciness and a touch of white pepper. The soft and juicy palate is supported by fine acidity. It sings on the palate!",
#         "rating": "90.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "3",
#         "grape": "",
#         "name": "Laurenz V Singing Gruner Veltliner 2010",
#         "notes": "A very attractive fruit bouquet yields apple, peach and citrus aromas along with a typical Veltliner spiciness and a touch of white pepper. The soft and juicy palate is supported by fine acidity. It sings on the palate!",
#         "rating": "88.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "4",
#         "grape": "",
#         "name": "Laurenz V Singing Gruner Veltliner 2011",
#         "notes": "A very attractive fruit bouquet yields apple, peach and citrus aromas along with a typical Veltliner spiciness and a touch of white pepper. The soft and juicy palate is supported by fine acidity. It sings on the palate!",
#         "rating": "88.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "5",
#         "grape": "",
#         "name": "Laurenz V Singing Gruner Veltliner 2013",
#         "notes": "A very attractive fruit bouquet yields apple, peach and citrus aromas along with a typical Veltliner spiciness and a touch of white pepper. The soft and juicy palate is supported by fine acidity. It sings on the palate!",
#         "rating": "89.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "8",
#         "grape": "",
#         "name": "Lava Cap Battonage Chardonnay 2012",
#         "notes": "This perfectly balanced wine begins with inviting aromas of dried flowers, twist of lime and lightly toasted oak. On the palate, enticing flavors of pear, lime, vanilla and butterscotch. The wine pairs nicely with roast chicken, turkey or pasta with cream sauce.",
#         "rating": "91.0",
#         "region": "Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "14",
#         "grape": "",
#         "name": "Lava Cap Reserve Chardonnay 2015",
#         "notes": "Zesty lemon and apple blossom aroma lead into pleasant apple and pear flavors. Vanilla notes complement a lightly toasted pie crust finish.",
#         "rating": "92.0",
#         "region": "El Dorado, Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "15",
#         "grape": "",
#         "name": "Lava Cap Reserve Chardonnay 2018",
#         "notes": "The 2018 vintage continues to consistently elevate Lava Cap\u2019s Chardonnay. Zesty lemon and apple blossom aroma lead into pleasant apple and pear flavors. Vanilla notes complement a lightly toasted pie crust finish.",
#         "rating": "92.0",
#         "region": "El Dorado, Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "16",
#         "grape": "",
#         "name": "Lava Cap Reserve Chardonnay 2016",
#         "notes": "Zesty lemon and apple blossom aroma lead into pleasant apple and pear flavors. Vanilla notes complement a lightly toasted pie crust finish.",
#         "rating": "92.0",
#         "region": "El Dorado, Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "18",
#         "grape": "",
#         "name": "Lava Cap Sauvignon Blanc 2015",
#         "notes": "An expressive aromatic wine displays note soft kiwi, celery and asian pear. The wines liveliness accents flavors of grapefruit, white peach and casaba melon.  The finish is smooth and long with a touch of supple fleshiness.",
#         "rating": "90.0",
#         "region": "El Dorado, Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "19",
#         "grape": "",
#         "name": "Lava Cap Sauvignon Blanc 2017",
#         "notes": "After the grapes are crushed, they are 100% fermented with 2 distinct yeast strains in small 500-gallon stainless steel tanks. After fermentation, the wine remains in the stainless steel tanks where it ages for an additional 4 months. The wine was bottled the first week of February and bottled aged for 4 weeks before being released. ",
#         "rating": "89.0",
#         "region": "El Dorado, Sierra Foothills, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "66",
#         "grape": "",
#         "name": "Lavinea Elton Chardonnay 2016",
#         "notes": "Pale straw in color with chartreuse and silver edge, the nose opens with mineral, wet rocks and umami notes laced with citrus and orange cream soda, and soft anise. The entry is delicate on the palate with a light creamy core, the layers of pears, white peaches, and honeysuckle flavors compete on the flinty and mineral finish. An elegant and long-lasting wine, with fresh layers upon layers which may demand another glass.",
#         "rating": "92.0",
#         "region": "Eola-Amity Hills, Willamette Valley, Oregon",
#         "variety": "White Wine"
#     },
#     {
#         "": "76",
#         "grape": "",
#         "name": "Lawson's Dry Hills Gewurztraminer 2009",
#         "notes": "The 2009 Lawson's Dry Hills Gew\u00fcrztraminer is a wonderful expression of a great vintage. The wine is luscious and round with gentle acidity, balanced by a hint of sweetness(9.2g/L). Lemon peel, marmalade, candyfloss, coriander, ginger and floral notes can all be found on the nose. The palate is mouthfilling and rich with lovely concentration. Lychee, lemon and Turkish delight flavours lead on to a long spicy finish. As the wine develops it will become more expressive on the nose and increasingly complex.",
#         "rating": "90.0",
#         "region": "New Zealand",
#         "variety": "White Wine"
#     },
#     {
#         "": "77",
#         "grape": "",
#         "name": "Lawson's Dry Hills Gewurztraminer 2014",
#         "notes": "The bouquet of this wine is beautifully scented with notes of rose petal, clove, lychee, ginger, citrus and much more... The palate is rich and round with a lovely mid-palate volume and a luscious texture. A sliver of sweetness provides softness to the finish. Overthe next eight to ten years this wine will develop musk, honey and toasty characters, while retaining its distinctive varietal appeal.",
#         "rating": "89.0",
#         "region": "Marlborough, New Zealand",
#         "variety": "White Wine"
#     },
#     {
#         "": "79",
#         "grape": "",
#         "name": "Lawson's Dry Hills Sauvignon Blanc 2014",
#         "notes": "Beautiful ripe passion fruit and citrus aromas leap from the glass. The palate display's a full array of flavour's from passion fruit, lime and tropical fruits, through to gentle fresh green herbs. This wine is finely balanced, the dry palate has crisp acidity and a lovely minerality.",
#         "rating": "89.0",
#         "region": "Marlborough, New Zealand",
#         "variety": "White Wine"
#     },
#     {
#         "": "81",
#         "grape": "",
#         "name": "Layer Cake Chardonnay 2011",
#         "notes": "The nose is reminiscent of Meyer lemons, preserved then diced up later in the year for seasoning in a meal, wet stones and Kaffir lime blossoms waft in and out as well. The wine builds in body and texture as it sits in your mouth. Layers of Kaffir lime, guava, andpineapple pour in at first, and then the light creamy texture of whipped lemon curd fills in the flavor palate. The finish is clean and crisp, lingering enough to make you want another sip\u2026 goahead, we'll make more next year, don't worry.",
#         "rating": "88.0",
#         "region": "Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "90",
#         "grape": "",
#         "name": "Layer Cake Virgin Chardonnay 2009",
#         "notes": "The Virgin Chardonnay is so named because it never comes in contact with any oak. Our fellow wine lovers have expressed our shared interest in getting back to what Chardonnay used to be: Clean, crisp, layered, refreshing fruit, a hint of summer, with none of the overbearing heaviness of oak. If the taste of buttered popcorn is what you crave, you'd do better finding it at the movies than in a bottle of wine.",
#         "rating": "87.0",
#         "region": "Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "93",
#         "grape": "",
#         "name": "Le Bonheur Chardonnay 1999",
#         "notes": "Medium-bodied, fresh and dry, this wine has characteristic lemon/clove flavors. These delightful flavors are balanced with vanilla tones, which create the lingering, refreshing aftertaste of a fine, new-style Chardonnay. Delicious with lobster and other seafood, Parma ham, thinly sliced smoked salmon, as well as lightly prepared pork, veal and chicken dishes.",
#         "rating": "88.0",
#         "region": "South Africa",
#         "variety": "White Wine"
#     },
#     {
#         "": "112",
#         "grape": "",
#         "name": "Le Casematte Peloro Bianco 2017",
#         "notes": "Bright straw yellow in color. The nose boasts notes of white- and yellow-fleshed fruit, floral aromas of mimosas and chamomile, mineral aromas and Mediterranean herbs. On the palate, the wine is fresh and tangy with pleasant fruit and a long, invigorating finale heightened by lively citrus notes. ",
#         "rating": "91.0",
#         "region": "Sicily, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "128",
#         "grape": "",
#         "name": "Le Cirque Grenache Gris 2014",
#         "notes": "Medium to full-bodied and very aromatic, with intense fruit, floral notes, green herb character and a light spiciness on the nose.",
#         "rating": "90.0",
#         "region": "France",
#         "variety": "White Wine"
#     },
#     {
#         "": "129",
#         "grape": "",
#         "name": "Le Cirque Grenache Gris 2015",
#         "notes": "Medium to full-bodied and very aromatic, with intense fruit, floral notes, green herb character and a light spiciness on the nose.",
#         "rating": "89.0",
#         "region": "France",
#         "variety": "White Wine"
#     },
#     {
#         "": "145",
#         "grape": "",
#         "name": "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2014",
#         "notes": "Planted half in 1964 and half in 1999, this is an elegant, refined fruit-driven wine with a good structured impression on the palate.The Kimmeridgian escarpment of Fourchaume is reputed to produce some of the best Chablis wines and the South West exposure of the vines means that they bask in the warm afternoon sun.",
#         "rating": "91.0",
#         "region": "Chablis, Burgundy, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "146",
#         "grape": "",
#         "name": "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2015",
#         "notes": "Planted half in 1964 and half in 1999, this is an elegant, refined fruit-driven wine with a good structured impression on the palate. The Kimmeridgian escarpment of Fourchaume is reputed to produce some of the best Chablis wines -- and the South West exposure of the vines means that they bask in the warm afternoon sun. Vinified in stainless steel tanks (89%) to preserve the minerality and freshness, and in oak barrels (11%) of 228-litres to add more complex notes, this wine will continue to improve for the next 15 years or so.",
#         "rating": "91.0",
#         "region": "Chablis, Burgundy, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "147",
#         "grape": "",
#         "name": "Le Domaine D'Henri Chablis Fourchaume Premier Cru Vieilles Vignes 2014",
#         "notes": "This wine offers notes of forest floor and a racy, balanced palate, underlined by good acidity.",
#         "rating": "93.0",
#         "region": "Chablis, Burgundy, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "153",
#         "grape": "",
#         "name": "Le Due Terre Colli Orientali del Friuli Sacrisassi 2005",
#         "notes": "Bright straw yellow. Intense and persistent floral aromas. Dry, full-bodied, potent and warm. Finishes very long. Perfect for white meats and roasted whole fish as well as fish soup.    ",
#         "rating": "95.0",
#         "region": "Friuli-Venezia Giulia, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "154",
#         "grape": "",
#         "name": "Le Due Terre Colli Orientali del Friuli Sacrisassi 2007",
#         "notes": "Bright straw yellow. Intense and persistent floral aromas. Dry, full-bodied, potent and warm. Finishes very long. Perfect for white meats and roasted whole fish as well as fish soup. ",
#         "rating": "90.0",
#         "region": "Friuli-Venezia Giulia, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "201",
#         "grape": "",
#         "name": "Le Macchiole Paleo Bianco 2007",
#         "notes": "Yellow hay color with greenish reflections. White peach, vanilla yellow citrus and nectarine bouquet. Great minerality. To the palate the wine is sapid and fresh, well balance between the fruit and the barrique. ",
#         "rating": "90.0",
#         "region": "Tuscany, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "202",
#         "grape": "",
#         "name": "Le Macchiole Paleo Bianco 2013",
#         "notes": "Paleo Bianco is an original blend of Sauvignon Blanc and Chardonnay yet with a strong Mediterranean character and an excellent balance. Perfect for pairing with seafood this white does not shy from a medium to long aging in bottle.",
#         "rating": "91.0",
#         "region": "Tuscany, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "203",
#         "grape": "",
#         "name": "Le Macchiole Paleo Bianco 2015",
#         "notes": "1991 born the first Paleo Bianco, a very small production intended primarily for local restaurants. Today the Paleo Bianco is an original blend of Sauvignon Blanc and Chardonnay yet with a strong Mediterranean character and an excellent balance. Perfect for pairing with seafood this white does not shy from a medium to long aging in bottle.",
#         "rating": "93.0",
#         "region": "Tuscany, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "204",
#         "grape": "",
#         "name": "Le Macchiole Paleo Bianco 2016",
#         "notes": "This blend features a Mediterranean character and good balance. It pairs wonderfully with fish-based dishes.",
#         "rating": "93.0",
#         "region": "Tuscany, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "205",
#         "grape": "",
#         "name": "Le Macchiole Paleo Bianco 2017",
#         "notes": "Paleo Bianco today is a silky, mineral-driven blend of Chardonnay  and Sauvignon Blanc with loads of savory Mediterranean character. Deep aromas of lime and white flowers and a delicate spicy note reminiscent of almond and hazelnut.",
#         "rating": "92.0",
#         "region": "Tuscany, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "228",
#         "grape": "",
#         "name": "Le P'tit Paysan Jack's Hill Chardonnay 2011",
#         "notes": "Flint, sea air, meyer lemon and hints of brioche. Broad on the palate without losing focus. Finishes with bright acidity, lemon curd and salty minerality.",
#         "rating": "92.0",
#         "region": "Monterey, Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "229",
#         "grape": "",
#         "name": "Le P'tit Paysan Jack's Hill Chardonnay 2013",
#         "notes": "Picked at moderate sugars and fermented in a combination of stainless steel and neutral oak. Neutral oak aged, barrel stirred with partial secondary fermentation. This wine is bright, with orchard fruit giving way to an intense minerality.",
#         "rating": "92.0",
#         "region": "Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "230",
#         "grape": "",
#         "name": "Le P'tit Paysan Jack's Hill Chardonnay 2015",
#         "notes": "Bright, with orchard fruit giving way to an intense minerality.",
#         "rating": "89.0",
#         "region": "Monterey, Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "231",
#         "grape": "",
#         "name": "Le P'tit Paysan La Marea Albarino 2014",
#         "notes": "Kristy Vineyard is on a bench overlooking the Salinas River mainly consisting of calcium rich shale soils and ripens at low sugar and high acids. Cold fermented in stainless steel for aromatic intensity. Citrus blossom and crushed seashell aromas, elegant texture and bright acidity. ",
#         "rating": "92.0",
#         "region": "Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "232",
#         "grape": "",
#         "name": "Le P'tit Paysan La Marea Albarino 2015",
#         "notes": "Kristy Vineyard is on a bench overlooking the Salinas River mainly consisting of calcium rich shale soils and ripens at low sugar and high acids. Cold fermented in stainless steel for aromatic intensity. Citrus blossom and crushed seashell aromas, elegant texture and bright acidity. ",
#         "rating": "89.0",
#         "region": "Central Coast, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "247",
#         "grape": "",
#         "name": "Le Roi des Pierres Sancerre 2014",
#         "notes": "Intense aromas of citrus and grapefruit entice the senses, unfolding to reveal exotic fruits (passion fruit and kiwi) and a pleasant mineral character. Round and substantial, the palate offersa fresh, balanced acidity. A stunning silex Sancerre!",
#         "rating": "90.0",
#         "region": "Sancerre, Loire, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "248",
#         "grape": "",
#         "name": "Le Roi des Pierres Sancerre 2015",
#         "notes": "Intense aromas of citrus and grapefruit entice the senses, unfolding to reveal exotic fruits (passion fruit and kiwi) and a pleasant mineral character. Round and substantial, the palate offersa fresh, balanced acidity. A stunning silex Sancerre!",
#         "rating": "90.0",
#         "region": "Sancerre, Loire, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "249",
#         "grape": "",
#         "name": "Le Roi des Pierres Sancerre 2016",
#         "notes": "This Sancerre is an enchanting pale gold yellow with green hints. Concentrated aromas of exotic fruits, grapefruit, passion fruit, mango and blood orange tempt the senses before unfolding to a structured, mineral-driven palate with a graphite finish that evokes the flint terroir of St. Gemme. Notes of orange zest linger on the beautifully balanced finish that leaves a saline impression.",
#         "rating": "91.0",
#         "region": "Sancerre, Loire, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "277",
#         "grape": "",
#         "name": "Le Vieux Donjon Chateauneuf-du-Pape Blanc 2006",
#         "notes": "A tiny bit of superb white wine made.  Well-defined and shapely so that they may be enjoyed right away, Vieux Donjon Chateauneufs, nevertheless age slowly and magnificently.",
#         "rating": "91.0",
#         "region": "Chateauneuf-du-Pape, Rhone, France",
#         "variety": "White Wine"
#     },
#     {
#         "": "278",
#         "grape": "",
#         "name": "Le Vigne di Eli Etna Bianco 2012",
#         "notes": "A project by Marco de Grazia, named for his daughter Elena (Eli), that donates a large portion of the proceeds to a children's hospital in Florence. The labels are drawings by Elena. This is 100% Carricante from Mount Etna. Vinified in stainless steel vats through cold maceration and aged in 10lh barrell and tonneaux for 10 months, last passage in bottle for further 8 months. Straw yellow colour, it shows delicate orange blossom and a dainty touch of white flower, lime wood and vanilla on the nose, sapid on the palate. Fish, flesh or foul, all are fine, if very gently cooked. It loves seafood, particularly over pasta: after all, it is Sicilian. ",
#         "rating": "91.0",
#         "region": "Sicily, Italy",
#         "variety": "White Wine"
#     },
#     {
#         "": "295",
#         "grape": "",
#         "name": "Leasingham Bin 7 Riesling 2001",
#         "notes": "This renowned wine was first released in 1967. Its aromatic, dry wine displaying excellent lime and citrus varietal flavours. Sourced from a selection of sights throughout the Valley, the wines length of flavour and elegant overall structure serves to reinforce the Clare Valleys enviable reputation for premium Riesling.",
#         "rating": "87.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "296",
#         "grape": "",
#         "name": "Leasingham Bin 7 Riesling 2003",
#         "notes": "This renowned wine was first released in 1967. Its aromatic, dry wine displaying excellent lime and citrus varietal flavours. Sourced from a selection of sights throughout the Valley, the wines length of flavour and elegant overall structure serves to reinforce the Clare Valleys enviable reputation for premium Riesling.",
#         "rating": "89.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "297",
#         "grape": "",
#         "name": "Leasingham Bin 7 Riesling 2004",
#         "notes": "\"Bright, impeccably balanced and appealing for its distinctly peppery grapefruit, green apple and floral aromas and flavors, which linger effortlessly on the dry finish.\"",
#         "rating": "90.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "298",
#         "grape": "",
#         "name": "Leasingham Bin 7 Riesling 2005",
#         "notes": "\"...offering bold flavors of honeycoated minerals perked by curls of lime zest. Firmly built and close to dry, you can drink it now for its power and fruit, or hold it up to 10 years or more...\"",
#         "rating": "91.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "304",
#         "grape": "",
#         "name": "Leasingham Magnus Riesling 2003",
#         "notes": "This wine is pale straw in color with brilliant green hues. On the nose the wine shows lifted, fresh pineapple fragrance with citrus spice. The palate shows punchy, ripe lemon, citrus spice with fleshy fruit sweetness. Coupled with fine mouth-watering acidity, the finish is fresh and lively. Enjoy now or cellar for up to 5-8 years.",
#         "rating": "87.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "305",
#         "grape": "",
#         "name": "Leasingham Magnus Riesling 2006",
#         "notes": "The 2006 Magnus Riesling displays all the hallmarks of fine Clare Valley Riesling - juicy acidity, lemony citrus and fullness of flavor. ",
#         "rating": "90.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "306",
#         "grape": "",
#         "name": "Leasingham Magnus Riesling 2007",
#         "notes": "In its inaugural release, the 2006 Magnus Riesling displays all the hallmarks of fine Clare Valley Riesling; juicy acidity, lemony citrus and fullness of flavor. The palate shows fresh punchy citrus fruit balanced out by delicious, tangy acidity, and finishes long and refreshing.",
#         "rating": "91.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "307",
#         "grape": "",
#         "name": "Leasingham Magnus Riesling 2004",
#         "notes": "Riesling thrives in the warm, sunny days of the Clare Valley, with cool night temperatures ensuring the wines stay fresh and balanced, with racy acidity. The vineyards that provide fruit for the Leasingham Magnus Riesling are characterized by high altitude and lean, slate soils.",
#         "rating": "89.0",
#         "region": "Clare Valley, South Australia, Australia",
#         "variety": "White Wine"
#     },
#     {
#         "": "321",
#         "grape": "",
#         "name": "L'Ecole 41 Barrel Fermented Semillon 2002",
#         "notes": "Rich in flavor and body, this wine shows honey, melon and soft tropical fruit flavors, with a hint of apricot and fig. The viscous mouth feel integrates these fruit components with a touch of vanilla and lemon, resulting in a crisp long finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "322",
#         "grape": "",
#         "name": "L'Ecole 41 Barrel Fermented Semillon 2004",
#         "notes": "\"Few Semillons show their richness and complexity as those produced in Washington State.  Our cool harvest nights help to ensure crisp natural acidity, making this a wonderful food pairing wine.  Try it with a goat cheese appetizer, spicy seafood, or your traditional Thanksgiving turkey and dressing.\"",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "323",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2004",
#         "notes": "\"The structure and backbone of this wine comes from the slightly cooler growing conditions of Fair Acre Vineyard and Evergreen Vineyards, with the riper melon and tropical flavors accentuated by the warmer Sagemoor and Goose Ridge sites.  Crisp acidity, ripe tropical flavors and a slight mineral edge harmonize with the richness of this Burgundian style Chardonnay.\"",
#         "rating": "87.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "324",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2006",
#         "notes": "Elegantly balanced, this Burgundian style Chardonnay shows Fuji apple, Asian pear and ripe pineapple and tropical flavors with subtle mineral and spice that gain complexity on a long, robust finish.",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "325",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2005",
#         "notes": "\"Some of the best Chardonnays in Washington State are grown in the slightly cooler growing conditions of Yakima Valley and in the northern latitudes of the Columbia Valley.   Fair Acre Vineyard (Yakima Valley) provides ripe tropical fruit, while Evergreen (latitude 47 on the Columbia River) contributes crisp acidity and minerality.  The old vines at the warmer Sagemoor Vineyard provide a nuance of ripe melon and pear on this Burgundian style Chardonnay.\"",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "326",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2008",
#         "notes": "This elegantly balanced Chardonnay shows robust acidity and purity of fruit with subdued tropical fruit, orange blossom and Asian pear flavors and subtle mineral nuances that gain complexity on a long, robust finish.",
#         "rating": "88.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "327",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2009",
#         "notes": "Some of the best Chardonnays in Washington State are grown in the slightly cooler growing conditions of Yakima Valley and in the northern latitudes of the Columbia Valley. The Schmitt Vineyard (Yakima Valley) provides nice tropical fruit, while Evergreen (latitude 47 on the Columbia River) contributes crisp acidity and minerality.  ",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "328",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2007",
#         "notes": "This wine is a blend of three distinguished vineyards: 52% Schmitt Vineyard; 36% Evergreen and 12% Bacchus.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "329",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2012",
#         "notes": "This beautifully expressive Chardonnay offers an enticing mix of tropical fruit, fresh apple, and old world characters of flint and slate. The elegant structure of this wine is finely balanced between richness and minerality, adding complexity on the clean, lingering finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "330",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2013",
#         "notes": "This beautifully expressive Chardonnay offers an enticing mix of tropical fruit, apple, and old world characters of flint and slate. The rich structure of this wine is finely balanced with texture and minerality, adding complexity on the full, lingering finish.",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "331",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2014",
#         "notes": "This beautifully expressive Chardonnay offers an enticing mix of tropical fruit, apple, and nutmeg with old world characters of flint and slate. The rich structure of this wine is finely balanced with texture and minerality, adding complexity on the full, lingering finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "332",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2015",
#         "notes": "This beautifully expressive Chardonnay offers an enticing mix of tropical fruit, apple, and nutmeg with old world characters of flint and slate. The rich structure of this wine is finely balanced with texture and minerality, adding complexity on the full, lingering finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "333",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2016",
#         "notes": "This beautifully expressive Chardonnay offers an inviting mix of baked apple, dried mango, brioche, and stone. Complex, with excellent balance, the finish builds to a long fruit-mineral-spice aftertaste.",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "334",
#         "grape": "",
#         "name": "L'Ecole 41 Chardonnay 2018",
#         "notes": "This classic Chardonnay offers an inviting mix of baked apple, Asian pear, and stone.  With lemon oil and brioche on the mid-palate, this wine lively builds to a long mineral finish.",
#         "rating": "89.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "361",
#         "grape": "",
#         "name": "L'Ecole 41 Fries Vineyard Semillon 2002",
#         "notes": "The Fries Semillon shows aromas of ripe tropical fruit and apricot with a vanilla-orange nose. The bright crisp mouth shows pear and apple flavors with lemon peel and slight clove on the finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "362",
#         "grape": "",
#         "name": "L'Ecole 41 Fries Vineyard Semillon 2003",
#         "notes": "The Fries Semillon shows aromas of ripe tropical fruit and apricot with a vanilla-orange nose. The bright crisp mouth shows pear and apple flavors with lemon peel and slight clove on the finish.",
#         "rating": "93.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "363",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2007",
#         "notes": "Luminesce captures the refreshing and illuminating aspect of this classic Bordeaux blend. This Estate wine is anchored with Semillon at its core, providing lush tones of melon, pear and honeysuckle. The introduction of Sauvignon Blanc broadens the flavor and texture, elevating the crisp, floral and mineral side of the wine. Like our red Bordeaux blend Perigee, Luminesce exemplifies the distinct, signature characteristics of our Estate Seven Hills Vineyard. ",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "364",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2008",
#         "notes": "Rich and complex, this Estate Semillon/Sauvignon Blanc shows exotic star fruit, papaya and tropical flavors with lychee and melon on a spicy, crisp mineral finish.",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "365",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2009",
#         "notes": "Rich and complex, our Estate Luminesce shows exotic spice, star fruit and papaya aromas. A creamy edge enhances the lush, tropical fruit flavors which gain depth on the lengthy finish.",
#         "rating": "91.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "366",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2010",
#         "notes": "Rich and integrated, our Estate Luminesce shows exotic spice, kiwi, star fruit and mineral aromas. A citrus edge enhances the creamy, wet stone and passion fruit flavors which gain depth on a lengthy finish. ",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "367",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2012",
#         "notes": "Rich and integrated, our Estate Luminesce shows lanolin, apricot, kiwi, star fruit and mineral aromas. A citrus edge enhances the creamy, wet stone and passion fruit flavors which gain depth on a lengthy clean finish.",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "368",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2011",
#         "notes": "Rich and integrated, our Estate Luminesce shows exotic spice, kiwi, star fruit and mineral aromas. A citrus edge enhances the creamy, wet stone and passion fruit flavors which gain depth on a lengthy finish.",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "369",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2013",
#         "notes": "Rich and harmonious our estate Luminesce offers creamy aromas and flavors of kiwi, star and passion fruits. The finish is seamless, lingering with citrus and mineral elements. ",
#         "rating": "92.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "370",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2014",
#         "notes": "Rich and harmonious our estate Luminesce offers aromas and flavors of lemongrass, kiwi, white peach and melon. The finish is seamless, lingering with citrus and mineral elements. ",
#         "rating": "91.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "371",
#         "grape": "",
#         "name": "L'Ecole 41 Luminesce Seven Hills Vineyard 2016",
#         "notes": "Luminesce, our white Bordeaux blend, is anchored with Semillon at its core, providing lush tropical fruit and honeysuckle. The introduction of Sauvignon Blanc broadens the flavor and texture, elevating the crisp, floral, and mineral side of the wine.",
#         "rating": "90.0",
#         "region": "Walla Walla Valley, Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "372",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2011",
#         "notes": "This fresh, vibrant and fruity Chenin Blanc shows rich floral aromatics of jasmine, lavender, and orange blossom with flavors of star fruit, apple and apricot on a crisp mineral finish. ",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "373",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2010",
#         "notes": "This fresh, tart and delightfully fruity Chenin Blanc shows Asian pear, lavender, perfumed honeysuckle and orange blossom aromas with flavors of sweet apple, apricot and pink grapefruit on a robust and crisp mineral finish.",
#         "rating": "91.0",
#         "region": "Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "374",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2014",
#         "notes": "This fresh and vibrant Chenin Blanc shows highly expressive aromatics of passion fruit and orange blossom, with flavors of star fruit, tangerine and apple on a balanced, crisp mineral finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "375",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2013",
#         "notes": "This fresh and vibrant Chenin Blanc shows abundant expressive aromatics of jasmine, passion fruit, and orange blossom with flavors of star fruit and apple on a balanced, crisp mineral finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "376",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2012",
#         "notes": "L'Ecole N\u00ba 41 has produced this old vine, Vouvray style Chenin Blanc since 1987. Jean Ferguson, L'Ecole N\u00ba 41's founding winemaker, loved this wine and crafted her version of Vouvray through cold fermentation to enhance the fruity and floral esters. ",
#         "rating": "92.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "377",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2015",
#         "notes": "#78",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "378",
#         "grape": "",
#         "name": "L'Ecole 41 Old Vines Chenin Blanc 2016",
#         "notes": "L\u2019Ecole N\u00b0 41 has produced this old vine, crisp and aromatic Vouvray-style Chenin Blanc since 1987.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "386",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2005",
#         "notes": "Few Semillons show their richness and complexity as those produced in Washington State.  Our cool harvest nights help to ensure crisp natural acidity, making this a wonderful food pairing wine.  Try it with a goat cheese appetizer, spicy seafood or your traditional Thanksgiving turkey and dressing.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "387",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2006",
#         "notes": "Blend: 86% Semillon, 14% Sauvignon Blanc ",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "388",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2007",
#         "notes": "Remarkably brilliant with rich fruit and balanced acidity, this wine shows fragrant citrus blossom, tangerine and floral aromas, with melon, fresh apple, pear, lychee nut and key-lime flavors on a honeysuckle mineral-rich finish. Try it with a goat cheese appetizer, spicy seafood or your traditional Thanksgiving turkey and dressing.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "389",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2008",
#         "notes": "Remarkably brilliant with rich fruit and balanced acidity, this wine shows fragrant citrus blossom, lemon and floral aromas, with melon, pear, lychee nut and key-lime flavors on a honeysuckle mineral-rich finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "390",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2010",
#         "notes": "Remarkably brilliant with vibrant fruit and balanced acidity, this wine shows fragrant citrus blossom and honey aromas, with pretty layers of lemon bar, apricot and keylime expanding on a balanced finish.",
#         "rating": "87.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "391",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2009",
#         "notes": "83% Semillon, 17% Sauvignon Blanc. ",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "392",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2012",
#         "notes": "Remarkably brilliant with vibrant fruit and balanced acidity, this pretty floral wine shows citrus blossom, jasmine and honeyed aromas, with layers of lemon custard, apricot and key-lime expanding on a balanced finish.  ",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "393",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2013",
#         "notes": "Few Semillons show their richness and complexity as those produced in  Washington State. The  cool harvest nights help to ensure crisp natural acidity,  making this a wonderful food pairing wine. The wine is remarkably brilliant with vibrant fruit and balanced acidity, this pretty floral wine shows citrus blossom, jasmine and honeyed aromas, with layers of lemon custard, apricot and key-lime expanding on a balanced finish.",
#         "rating": "90.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "394",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2015",
#         "notes": "Rich with vibrant fruit and balanced acidity, this wine shows pretty orange blossom, apple and melon aromas, with layers of lemon custard, fresh apricot and honeysuckle flavors expanding on a balanced finish. Few Semillons show their richness and complexity as those produced in Washington State. Our cool harvest nights help to ensure crisp natural acidity, making this a wonderful food pairing wine.",
#         "rating": "89.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "395",
#         "grape": "",
#         "name": "L'Ecole 41 Semillon 2018",
#         "notes": "This aromatic gem shows multiple layers of stone fruit, melon, and floral aromas with flavors of pear and lemon custard on a refreshingly balanced finish.",
#         "rating": "91.0",
#         "region": "Columbia Valley, Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "413",
#         "grape": "",
#         "name": "L'Ecole 41 Walla Voila Chenin Blanc 2009",
#         "notes": "The Chenin Blanc was harvested in the early morning and promptly delivered to the winery. The fruit was gently whole-cluster pressed to minimize phenolics and solids. The settled juice was fermented slowly with a classic Vouvray yeast at cold temperatures to yield rich and fruity flavors. After three months the fermentation was stopped by cold suppression and the wine was filtered.",
#         "rating": "90.0",
#         "region": "Washington",
#         "variety": "White Wine"
#     },
#     {
#         "": "431",
#         "grape": "",
#         "name": "Leese-Fitch Chardonnay 2015",
#         "notes": "A rich golden hue in color, this medium-bodied Chardonnay shows enticing aromas of spiced applesauce and citrus. A rich palate showcases refreshing flavors of melon and soft vanilla leading to an exceptionally smooth and lengthy balanced finish.",
#         "rating": "90.0",
#         "region": "California",
#         "variety": "White Wine"
#     },
#     {
#         "": "432",
#         "grape": "",
#         "name": "Leese-Fitch Chardonnay 2016",
#         "notes": "A rich golden hue in color, this medium-bodied Chardonnay shows enticing aromas of spiced applesauce and citrus. A rich palate showcases refreshing flavors of melon and soft vanilla leading to an exceptionally smooth and lengthy balanced finish.",
#         "rating": "90.0",
#         "region": "California",
#         "variety": "White Wine"
#     },
#     {
#         "": "433",
#         "grape": "",
#         "name": "Leese-Fitch Chardonnay 2017",
#         "notes": "The 2017 Leese-Fitch Chardonnay hails from fruit picked at both ends of the Lodi appellation. This blend gives the wine a core of cool climate fruit with essence of lemon, apple, and pear. The Clarksburg Viognier gives the blend some additional complexity with notes of apricot and tangerine, rounding out the mouthfeel.",
#         "rating": "90.0",
#         "region": "California",
#         "variety": "White Wine"
#     },
#     {
#         "": "435",
#         "grape": "",
#         "name": "Leese-Fitch Sauvignon Blanc 2010",
#         "notes": "The 2010 Leese-Fitch Sauvignon Blanc is a crisp and refreshing wine. This wine has a high-tone citrus zest aroma with minerality reminiscent of a brisk ocean breeze. There's a hint of freshly squeezed grapefruit juice and tropical Pina Colada. The palate is zippy and alive with Lemon grass spice, but balanced with a touch of creamy tapioca to round out the mid-palate. ",
#         "rating": "90.0",
#         "region": "California",
#         "variety": "White Wine"
#     },
#     {
#         "": "436",
#         "grape": "",
#         "name": "Leese-Fitch Sauvignon Blanc 2015",
#         "notes": "Zesty and refreshing, this Sauvignon Blanc has enticing aromas of Mexican guava and pineapple that carry over to the palate. Just off-dry, the body of this wine is juicy with a crisp balanced acidity. ",
#         "rating": "89.0",
#         "region": "California",
#         "variety": "White Wine"
#     },
#     {
#         "": "437",
#         "grape": "",
#         "name": "Leese-Fitch Sauvignon Blanc 2017",
# ...
#     },
#     {
#         "": "677",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2007",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces.",
#         "rating": "90.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "678",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2008",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces.",
#         "rating": "90.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "679",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2010",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces. This wine is part of a line from Leth that displays complexity in flavor, minerality and durability.",
#         "rating": "91.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "680",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2012",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces. This wine is part of a line from Leth that displays complexity in flavor, minerality and durability.",
#         "rating": "88.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "681",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2015",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces. This wine is part of a line from Leth that displays complexity in flavor, minerality and durability.",
#         "rating": "91.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "682",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2016",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces. This wine is part of a line from Leth that displays complexity in flavor, minerality and durability.",
#         "rating": "90.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "683",
#         "grape": "",
#         "name": "Leth Steinagrund Gruner Veltliner 2017",
#         "notes": "The nose combines spice with a reductive fruit; the palate displays peppery notes; a classic Veltliner from loess terraces. This wine is part of a line from Leth that displays complexity in flavor, minerality and durability.",
#         "rating": "90.0",
#         "region": "Austria",
#         "variety": "White Wine"
#     },
#     {
#         "": "686",
#         "grape": "",
#         "name": "Levendi Sweeney Ranch Chardonnay 2010",
#         "notes": "Beautifully ripe apple with a hint of caramel and oak spice, filled in with lemon chiffon notes. Caramelized apple and lemon vanilla cream flavors on the palate, with the texture gracefully balanced between a rich center and a crisp finish.",
#         "rating": "93.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "718",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2006",
#         "notes": "Our Barcaglia Lane Chardonnay is sourced from a single rolling vineyard in the Russian River Valley. Developed for us by the Dutton Family in 1998, the site consists of 3 sloping blocks planted to three different clones \u2013 15, Dijon 95, and Old Wente \u2013 which yield increasingly distinctive and complex fruit characters. Tangerine, citrus and sandalwood spice aromas are overlaid with a hint of honey. The wine is anchored in fragrant citrus fruits and framed nicely with toasty oak and acidity that brings great balance, integration and length to the palate.",
#         "rating": "90.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "719",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2008",
#         "notes": "Record low yields in 2008 slashed production by 40%, resulting in excellent fruit quality. Fragrant, ripe orange and vanilla are naturally appealing with notes of cinnamon, oak spice and piecrust. An orchard of core citrus fruits forms the supple and satisfying palate with lively acidity and an exotic, lingering finish.",
#         "rating": "90.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "720",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2009",
#         "notes": "Like the Reserve Chardonnay, our Barcaglia Lane bottling receives four additional months of barrel aging on the lees resulting in broad texture and fine detail. It is sourced from a single rolling vineyard in the Russian River Valley, part of the famed Dutton Ranch. Planted for us in 1998, the site consists of 3 sloping blocks planted to three different clones. The wine is strikingly aromatic with ripened mandarin, blood orange and spiced apple fruits, shot through with honeysuckle and hazelnut spice. Voluptuously built with plenty of curves, the richly woven palate gives way to a lively citrus laced finish.",
#         "rating": "91.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "721",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2015",
#         "notes": "From Dutton Ranch vineyards, the 2015 Barcaglia Lane Chardonnay is a beach party in a bottle, with showers of citrus and sweet tropical blossoms, cr\u00e8me brulee, and Tahitian spice. The palate is a tsunami of tropical fruit with tons of native acidity to keep the Aloha flowing.",
#         "rating": "90.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "722",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2014",
#         "notes": "2014 makes it three excellent vintages in a row for our Barcaglia Lane Chardonnay, sourced from a trio of clones at this Dutton Ranch vineyard. The wine is all succulent, ripe citrus with toasty tangerine, orange zest and lemon-lime. Toasty gun-barrel oak and vanilla, together with tropical fruit skin and spice completes the package. Buttressed by a framework of native acidity the wine is gauzy in weight and texture, staying up in the palate before finishing with focus and clarity.",
#         "rating": "92.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "723",
#         "grape": "",
#         "name": "Lewis Cellars Barcaglia Lane Chardonnay 2017",
#         "notes": "The nose alone takes our 2017 Barcaglia Lane Chardonnay to the highest level, with nectarine and vanilla chiffon, sterling rose and preserved lemon, mineral, and sweet oak spice. Deftly weighted with citrus and tree fruits the wine achieves balance through a ribbon of native acidity carrying on to a lengthy succulent finish.",
#         "rating": "92.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "742",
#         "grape": "",
#         "name": "Lewis Cellars Napa Valley Chardonnay 2008",
#         "notes": "Crafted from a combination of Oak Knoll vines and longer-hanging Carneros clusters, our 2008 Napa Valley Chardonnay is satisfyingly ripe, yet focused and fresh in the same sip. Showy stone fruit, pear, hazelnut and toasty oak spices spill from the glass. Rich-bodied, fruitful and round on the palate with vanilla and subtle minerality, the wine is threaded with lively acidity bringing length and focus to a fine finish.",
#         "rating": "91.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "743",
#         "grape": "",
#         "name": "Lewis Cellars Napa Valley Chardonnay 2015",
#         "notes": "Grapes for the 2015 Napa Chardonnay came in early and the wine centers around ripe Bosc pear and Fuji apple with delicious caramel custard, pie crust and hazelnut. Thickly textured and satiny smooth like Deux-Sevres butter, the richness and weight are buttressed with native acidity and subtle minerality bringing complexity and length to this delicious wine.",
#         "rating": "92.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "744",
#         "grape": "",
#         "name": "Lewis Cellars Napa Valley Chardonnay 2014",
#         "notes": "Another warm vintage and generous crop brought plenty of sun-kissed fruit for our 2014 Napa Valley Chardonnay. Ripened red and green pears with white peach are threaded with tantalizing cinnamon, nutmeg and caramel spices. The cream-textured palate is opulent, full-bodied and delicious with notes of vanilla, mineral and flaky croissant that carry into a long and increasingly focused finish. ",
#         "rating": "95.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "745",
#         "grape": "",
#         "name": "Lewis Cellars Napa Valley Chardonnay 2016",
#         "notes": "Golden delicious apple, honeysuckle blossom and toasty caramel spice aromas are served up generously in the 2016 Napa Chardonnay. Silky in texture with ripe tree fruit and plenty of drive the wine is athletic and complex with a tail of smoky mineral and lees character.",
#         "rating": "92.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "764",
#         "grape": "",
#         "name": "Lewis Cellars Reserve Chardonnay 2008",
#         "notes": "Bottled unfined and unfiltered in December last year, our 2008 Reserve Chardonnay shows fantastic focus, complexity and richness. There is great breadth and allure in the nose of crushed blossoms and stone, lime zest, hazelnut and pear; but the palate takes center stage. Like a French kiss, the wine is sumptuous and silky-rich in texture with creamy minerality and endlessly intriguing notes of bread crust and caramel. The palate retains great focus and structure throughout, as it leads to a long, luxurious finish.",
#         "rating": "93.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "765",
#         "grape": "",
#         "name": "Lewis Cellars Reserve Chardonnay 2015",
#         "notes": "Neil Young's \"Cinnamon Girl\" best captures the character of our rocking 2015 Reserve Chardonnay. Ripe yet succulent D'Anjou pear, gardenia blossom, sweet mineral spice and toasty brioche aromas come singing through. Broad-shouldered, with creamy textured leesy flavors, the wine reaches great depth while maintaining precision and serious structure.",
#         "rating": "92.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "766",
#         "grape": "",
#         "name": "Lewis Cellars Reserve Chardonnay 2018",
#         "notes": "From the long growing season of 2018, this Napa Reserve Chardonnay has super showy aromatics, deliciously complex flavors and alluring texture that can\u2019t be captured in words. Opening with white flower blossoms, green pear, lime zest and crushed stone mineral the wine is fragrant and long-limbed. Profoundly rich and silky texture is underpinned with structural detail and a stunningly long tail.",
#         "rating": "93.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "767",
#         "grape": "",
#         "name": "Lewis Cellars Reserve Chardonnay 2017",
#         "notes": "Think of our 2017 Reserve Chardonnay as a Rolls Royce Wraith \u2013 offering a sumptuous interior with serious performance. A plethora of heady aromas alight from the glass with Anjou pear, warm brioche, sweet mineral spice and gardenia blossom. Lush yet lively with great depth and gauzy texture the wine shows impeccable build quality and attention to detail with a miles long finish.",
#         "rating": "93.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "769",
#         "grape": "",
#         "name": "Lewis Cellars Sauvignon Blanc 2016",
#         "notes": "The warm, vibrant character and seductive imagery of Paul Gauguin's Tahiti are captured in our 2016 Sauvignon Blanc. Awash in ripe mango, guava and papaya and laced with tropical blossoms, vanilla and spice, the wine is lush and luxuriant, fruitful to the core, yet draped in native acidity and a fleck of salinity that frame and lengthen the canvas.",
#         "rating": "90.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "770",
#         "grape": "",
#         "name": "Lewis Cellars Sauvignon Blanc 2018",
#         "notes": "Like a sailplane this 2018 Sauvignon Blanc soars with alluring floral spice, lemon-lime zest and hints of vanilla. A leading edge of native acidity frames a camber line of ripe mango and tropical fruit that tails gracefully with succulent lime skin and subtle mineral.",
#         "rating": "92.0",
#         "region": "Napa Valley, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "771",
#         "grape": "",
#         "name": "Lewis Cellars Sonoma Chardonnay 2014",
#         "notes": "Sourced from 40-year old vines the wine is unusually dense with super ripe blood orange, lime, honeysuckle and Fuji apple spice. Fabulous satiny texture and lemon confiture gain focus and brilliance with lots of sur-lie character en route to a long, happy ending.",
#         "rating": "93.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "772",
#         "grape": "",
#         "name": "Lewis Cellars Sonoma Chardonnay 2015",
#         "notes": "Blazing tropical fruit, exotic spices and sexy ripe citrus come together in this tangerine dream. Like a beach volleyball Olympian, the wine has explosive power plus tremendous depth and range on the palate. Richness and precision are continually on point, and the wine sets up high in the mouth before stretching out in a tanned and impossibly long-legged, leesy finish. ",
#         "rating": "92.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "773",
#         "grape": "",
#         "name": "Lewis Cellars Sonoma Chardonnay 2017",
#         "notes": "Chardonnay is whole cluster pressed, barrel fermented and aged sur lies with batonnage in 100% French oak for 11-15 months, undergoing 100% malolactic fermentation, then bottled unfined and unfiltered. ",
#         "rating": "92.0",
#         "region": "Russian River, Sonoma County, California",
#         "variety": "White Wine"
#     },
#     {
#         "": "774",
#         "grape": "",
#         "name": "Lewis Cellars Sonoma Valley Chardonnay 2008",
#         "notes": "Our Sonoma Chardonnay comes from some of the oldest Dutton Ranch plantings in Russian River. These vines consistently yield fruit of great complexity and intensity seldom found in other sites. Cooler temperatures toward the end of the 2008 growing season resulted in crisp, well-defined flavors and long ripening times. Ripe citrus, Tupelo honey and sweet floral notes combined with seductive oak and all-spice aromas are just the beginning. Sun-ripened citrus fruit flavors are framed with brilliant acidity giving this wine its trademark zest and tremendous length.",
#         "rating": "91.0",
#         "region": "Sonoma County, California",
#         "variety": "White Wine"
#     }
# ]

# %%
# Let's do the same thing now for wines with scores over 96.
# The difference here is that we need to convert the wine rating column to 
# floating type, so that we can compare the numbers to our desired score.


high_wines = []
for wine in wines:
    wine['rating'] = float(wine['rating']) 
    if wine['rating'] > 96:
        high_wines.append(wine)

with open('sample_data/high_wines.json', 'w') as f:
    json.dump(high_wines, f, sort_keys=True, indent=4)

# %% [markdown]
# ## Using Pandas
# Alternatively, you can use the Pandas library to load the CSV file and then extract the data. You'll need to install the Pandas library first. You can do this with the following command:
#
# ```bash
# pip install pandas
# ```
#
# Then, you can use the following code to load the CSV file and extract the data:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('sample_data/wine-ratings-small.csv')
# df.head()
# ```

# %%
import pandas as pd
df = pd.read_csv("sample_data/wine-ratings-small.csv", index_col=0) # read the csv file and set the index column to 0
df.head() # show the first 5 rows of the dataframe
# Out:
#                                        name  grape            region  \
# 0  Laurenz V Charming Gruner Veltliner 2013    NaN  Kamptal, Austria
# 1  Laurenz V Charming Gruner Veltliner 2014    NaN  Kamptal, Austria
# 2   Laurenz V Singing Gruner Veltliner 2007    NaN           Austria
# 3   Laurenz V Singing Gruner Veltliner 2010    NaN           Austria
# 4   Laurenz V Singing Gruner Veltliner 2011    NaN           Austria
#
#       variety  rating                                              notes
# 0  White Wine    90.0  Aromas of ripe apples and a typical Veltliner ...
# 1  White Wine    90.0  Aromas of ripe apples and a typical Veltliner ...
# 2  White Wine    90.0  A very attractive fruit bouquet yields apple, ...
# 3  White Wine    88.0  A very attractive fruit bouquet yields apple, ...
# 4  White Wine    88.0  A very attractive fruit bouquet yields apple, ...

# %% [markdown]
# ## Manipulate data with Pandas or as a dictionary
# At this point, you can use Pandas if you know how to use it. Otherwise, you can use the data as a dictionary. You can use the following code to extract the data:
#
# ```python
# data = df.to_dict()
# ```

# %%
dict_data = df.to_dict()
# You'll get several keys, one for each column in the dataframe. You can access the values of a column by using the column name as a key. You'll also
# get the index of each row as a key. You can access the values of a row by using the index as a key.

dict_data['name'] # get the values of the 'name' column
# sample output:
# {0: 'Laurenz V Charming Gruner Veltliner 2013',
# 1: 'Laurenz V Charming Gruner Veltliner 2014', ...}
# Out:
# {0: 'Laurenz V Charming Gruner Veltliner 2013',
#  1: 'Laurenz V Charming Gruner Veltliner 2014',
#  2: 'Laurenz V Singing Gruner Veltliner 2007',
#  3: 'Laurenz V Singing Gruner Veltliner 2010',
#  4: 'Laurenz V Singing Gruner Veltliner 2011',
#  5: 'Laurenz V Singing Gruner Veltliner 2013',
#  6: 'Lava Cap American River Red',
#  7: 'Lava Cap Barbera 2010',
#  8: 'Lava Cap Battonage Chardonnay 2012',
#  9: 'Lava Cap Cabernet Sauvignon 2013',
#  10: 'Lava Cap Cabernet Sauvignon 2016',
#  11: 'Lava Cap Petite Sirah 2013',
#  12: 'Lava Cap Petite Sirah 2014',
#  13: 'Lava Cap Petite Sirah 2016',
#  14: 'Lava Cap Reserve Chardonnay 2015',
#  15: 'Lava Cap Reserve Chardonnay 2018',
#  16: 'Lava Cap Reserve Chardonnay 2016',
#  17: 'Lava Cap Reserve Merlot 2015',
#  18: 'Lava Cap Sauvignon Blanc 2015',
#  19: 'Lava Cap Sauvignon Blanc 2017',
#  20: 'Lava Cap Syrah 2009',
#  21: 'Lava Cap Syrah 2014',
#  22: 'Lava Cap Syrah 2013',
#  23: 'Lava Vine Winery Knights Valley Reserve Cabernet Sauvignon 2013',
#  24: 'Lava Vine Winery Napa Valley Cabernet Sauvignon 2014',
#  25: 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2012',
#  26: 'Lava Vine Winery Napa Valley Reserve Cabernet Sauvignon 2013',
#  27: 'Lavau Chateauneuf-du-Pape 2016',
#  28: 'Lavau Chateauneuf-du-Pape 2014',
#  29: 'Lavau Chateauneuf-du-Pape 2015',
#  30: 'Lavau Gigondas 2013',
#  31: 'Lavau Gigondas 2013',
#  32: 'Lavau Gigondas 2014',
#  33: 'Lavau Gigondas 2015',
#  34: 'Lavau Gigondas 2016',
#  35: 'Lavau Rasteau 2015',
#  36: 'Lavau Rasteau 2016',
#  37: "L'Aventure Cabernet Sauvignon 2006",
#  38: "L'Aventure Chloe 2014",
#  39: "L'Aventure Cote A Cote 2006",
#  40: "L'Aventure Cote A Cote 2007",
#  41: "L'Aventure Cote A Cote 2010",
#  42: "L'Aventure Cote A Cote 2011",
#  43: "L'Aventure Cote A Cote 2014",
#  44: "L'Aventure Cote A Cote (slightly stained labels) 2012",
#  45: "L'Aventure Estate Cuvee (1.5 Liter Magnum) 2008",
#  46: "L'Aventure Estate Cuvee 2004",
#  47: "L'Aventure Estate Cuvee 2005",
#  48: "L'Aventure Estate Cuvee 2006",
#  49: "L'Aventure Estate Cuvee 2007",
#  50: "L'Aventure Estate Cuvee 2008",
#  51: "L'Aventure Estate Cuvee 2010",
#  52: "L'Aventure Estate Cuvee 2011",
#  53: "L'Aventure Estate Cuvee 2013",
#  54: "L'Aventure Estate Cuvee 2012",
#  55: "L'Aventure Estate Cuvee 2014",
#  56: "L'Aventure Estate Cuvee 2016",
#  57: "L'Aventure Optimus (1.5 Liter Magnum) 2012",
#  58: "L'Aventure Optimus 2005",
#  59: "L'Aventure Optimus 2007",
#  60: "L'Aventure Optimus 2008",
#  61: "L'Aventure Optimus 2011",
#  62: "L'Aventure Optimus 2015",
#  63: "L'Aventure Optimus 2016",
#  64: "L'Aventure Optimus 2017",
#  65: "L'Aventure Optimus 2012",
#  66: 'Lavinea Elton Chardonnay 2016',
#  67: 'Lavinea Elton Pinot Noir 2016',
#  68: 'Lavinea Lazy River Pinot Noir 2016',
#  69: 'Lavinea Nysa Pinot Noir 2016',
#  70: 'Lavinea Tualatin Pinot Noir 2016',
#  71: 'Lavinea Tualatin Pinot Noir 2017',
#  72: 'Lavradores de Feitoria Tres Bagos 2003',
#  73: 'Lavradores de Feitoria Tres Bagos 2004',
#  74: 'Law Estate Wines Audacious 2016',
#  75: 'Law Estate Wines Sagacious 2016',
#  76: "Lawson's Dry Hills Gewurztraminer 2009",
#  77: "Lawson's Dry Hills Gewurztraminer 2014",
#  78: "Lawson's Dry Hills Pinot Noir 2005",
#  79: "Lawson's Dry Hills Sauvignon Blanc 2014",
#  80: 'Layer Cake Cabernet Sauvignon 2010',
#  81: 'Layer Cake Chardonnay 2011',
#  82: 'Layer Cake Garnacha 2011',
#  83: 'Layer Cake Malbec 2008',
#  84: 'Layer Cake Primitivo aka Zinfandel 2008',
#  85: 'Layer Cake Shiraz 2008',
#  86: 'Layer Cake Shiraz 2009',
#  87: 'Layer Cake Shiraz 2014',
#  88: 'Layer Cake Shiraz 2013',
#  89: 'Layer Cake Shiraz 2010',
#  90: 'Layer Cake Virgin Chardonnay 2009',
#  91: 'Le Berne Vino Nobile di Montepulciano 2011',
#  92: 'Le Bonheur Cabernet Sauvignon 1997',
#  93: 'Le Bonheur Chardonnay 1999',
#  94: 'Le Brun de Neuville Authentique Brut Assemblage',
#  95: 'Le Cadeau Vineyard Diversite Pinot Noir 2014',
#  96: 'Le Cadeau Vineyard Diversite Pinot Noir 2015',
#  97: 'Le Cadeau Vineyard Rocheux Pinot Noir 2015',
#  98: 'Le Cadeau Vineyard Rocheux Pinot Noir 2016',
#  99: 'Le Cadeau Vineyard Rocheux Reserve Pinot Noir 2014',
#  100: 'Le Carre 2007',
#  101: 'Le Carre 2008',
#  102: 'Le Carre 2009',
#  103: 'Le Carre 2010',
#  104: 'Le Carre 2011',
#  105: 'Le Carre 2012',
#  106: 'Le Casematte Faro 2014',
#  107: 'Le Casematte Faro 2013',
#  108: 'Le Casematte Faro 2016',
#  109: "Le Casematte Nero d'Avola 2015",
#  110: 'Le Casematte Peloro Rosso 2014',
#  111: 'Le Casematte Peloro Rosso 2015',
#  112: 'Le Casematte Peloro Bianco 2017',
#  113: 'Le Casematte Peloro Rosso 2017',
#  114: 'Le Charmel Rhone Blend 2011',
#  115: 'Le Chiuse Brunello di Montalcino 2008',
#  116: 'Le Chiuse Brunello di Montalcino 2010',
#  117: 'Le Chiuse Brunello di Montalcino 2011',
#  118: 'Le Chiuse Brunello di Montalcino 2012',
#  119: 'Le Chiuse Brunello di Montalcino 2013',
#  120: 'Le Chiuse Brunello di Montalcino 2015',
#  121: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2011',
#  122: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2013',
#  123: 'Le Chiuse Brunello di Montalcino (375ML half-bottle) 2012',
#  124: 'Le Chiuse Brunello di Montalcino Riserva 2006',
#  125: 'Le Chiuse Brunello di Montalcino Riserva 2009',
#  126: 'Le Chiuse Rosso di Montalcino 2015',
#  127: 'Le Chiuse Rosso di Montalcino 2017',
#  128: 'Le Cirque Grenache Gris 2014',
#  129: 'Le Cirque Grenache Gris 2015',
#  130: 'Le Cirque Rouge 2014',
#  131: "Le Clos d'un Jour Un Jour sur Terre Cahors 2005",
#  132: 'Le Colture Brut Rose',
#  133: 'Le Colture Fagher Prosecco Superiore Brut',
#  134: 'Le Colture Prosecco Superiore di Cartizze',
#  135: 'Le Corti Chianti Classico 2011',
#  136: 'Le Corti Chianti Classico 2012',
#  137: 'Le Corti Chianti Classico 2013',
#  138: 'Le Corti Don Tommaso Chianti Classico 2007',
#  139: 'Le Corti Chianti Classico 2016',
#  140: 'Le Corti Don Tommaso Chianti Classico 2008',
#  141: 'Le Corti Don Tommaso Chianti Classico 2013',
#  142: 'Le Corti Don Tommaso Chianti Classico 2014',
#  143: 'Le Corti Don Tommaso Chianti Classico 2009',
#  144: 'Le Corti Tenuta Birillo Rosso 2010',
#  145: "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2014",
#  146: "Le Domaine D'Henri Chablis Fourchaume Premier Cru 2015",
#  147: "Le Domaine D'Henri Chablis Fourchaume Premier Cru Vieilles Vignes 2014",
#  148: 'Le Dome 2006',
#  149: 'Le Dome 2008',
#  150: 'Le Dome 2009',
#  151: 'Le Dome 2011',
#  152: 'Le Dome 2012',
#  153: 'Le Due Terre Colli Orientali del Friuli Sacrisassi 2005',
#  154: 'Le Due Terre Colli Orientali del Friuli Sacrisassi 2007',
#  155: 'Le Dome 2016',
#  156: 'Le Dome 2010',
#  157: 'Le Dome 2014',
#  158: 'Le Fonti Chianti Classico 2009',
#  159: 'Le Grand Courtage Blanc de Blancs Brut Bedazzled Bottle',
#  160: 'Le Grand Courtage Rose Brut Bedazzled Bottle',
#  161: 'Le Jas des Papes Chateauneuf-du-Pape 2010',
#  162: 'Le Macchiole (1.5 Liter Magnum) 2013',
#  163: 'Le Macchiole 1999',
#  164: 'Le Macchiole 2006',
#  165: 'Le Macchiole 2005',
#  166: 'Le Macchiole 2008',
#  167: 'Le Macchiole 2006',
#  168: 'Le Macchiole 2009',
#  169: 'Le Macchiole 2010',
#  170: 'Le Macchiole 2013',
#  171: 'Le Macchiole Messorio (1.5 Liter Magnum) 2010',
#  172: 'Le Macchiole 2012',
#  173: 'Le Macchiole Messorio 2000',
#  174: 'Le Macchiole Messorio 2002',
#  175: 'Le Macchiole Messorio 2003',
#  176: 'Le Macchiole Messorio 2005',
#  177: 'Le Macchiole Messorio 2007',
#  178: 'Le Macchiole Messorio 2009',
#  179: 'Le Macchiole Messorio 2010',
#  180: 'Le Macchiole Messorio 2012',
#  181: 'Le Macchiole Messorio 2011',
#  182: 'Le Macchiole Messorio 2013',
#  183: 'Le Macchiole Messorio 2014',
#  184: 'Le Macchiole Paleo (1.5 Liter Magnum) 2007',
#  185: 'Le Macchiole Paleo (1.5 Liter Magnum) 2009',
#  186: 'Le Macchiole Paleo (1.5 Liter Magnum) 2011',
#  187: 'Le Macchiole Paleo 1998',
#  188: 'Le Macchiole Paleo 2003',
#  189: 'Le Macchiole Paleo 2001',
#  190: 'Le Macchiole Paleo 2004',
#  191: 'Le Macchiole Paleo 2005',
#  192: 'Le Macchiole Paleo 2007',
#  193: 'Le Macchiole Paleo 2008',
#  194: 'Le Macchiole Paleo 2009',
#  195: 'Le Macchiole Paleo 2010',
#  196: 'Le Macchiole Paleo 2011',
#  197: 'Le Macchiole Paleo 2012',
#  198: 'Le Macchiole Paleo 2013',
#  199: 'Le Macchiole Paleo 2014',
#  200: 'Le Macchiole Paleo (3 Liter Bottle) 2011',
#  201: 'Le Macchiole Paleo Bianco 2007',
#  202: 'Le Macchiole Paleo Bianco 2013',
#  203: 'Le Macchiole Paleo Bianco 2015',
#  204: 'Le Macchiole Paleo Bianco 2016',
#  205: 'Le Macchiole Paleo Bianco 2017',
#  206: 'Le Macchiole Scrio 2004',
#  207: 'Le Macchiole Scrio 2001',
#  208: 'Le Macchiole Scrio 2005',
#  209: 'Le Macchiole Scrio 2006',
#  210: 'Le Macchiole Scrio 2010',
#  211: 'Le Macchiole Scrio 2012',
#  212: 'Le Macchiole Scrio 2011',
#  213: 'Le Macchiole Scrio 2013',
#  214: 'Le Mistral 2008',
#  215: 'Le Paradou Grenache 2012',
#  216: 'Le Macchiole Scrio 2015',
#  217: 'Le Potazzine Gorelli Brunello di Montalcino 1997',
#  218: 'Le Potazzine Gorelli Brunello di Montalcino 2008',
#  219: 'Le Potazzine Gorelli Brunello di Montalcino 2009',
#  220: 'Le Potazzine Gorelli Brunello di Montalcino 2011',
#  221: 'Le Potazzine Gorelli Brunello di Montalcino 2010',
#  222: 'Le Potazzine Gorelli Brunello di Montalcino 2012',
#  223: 'Le Potazzine Rosso di Montalcino 2012',
#  224: 'Le Potazzine Gorelli Brunello di Montalcino 2013',
#  225: 'Le Potazzine Rosso di Montalcino 2014',
#  226: 'Le Potazzine Rosso di Montalcino 2015',
#  227: 'Le Potazzine Rosso di Montalcino 2017',
#  228: "Le P'tit Paysan Jack's Hill Chardonnay 2011",
#  229: "Le P'tit Paysan Jack's Hill Chardonnay 2013",
#  230: "Le P'tit Paysan Jack's Hill Chardonnay 2015",
#  231: "Le P'tit Paysan La Marea Albarino 2014",
#  232: "Le P'tit Paysan La Marea Albarino 2015",
#  233: "Le P'tit Paysan La Marea Grenache 2013",
#  234: "Le P'tit Paysan Le P'tit Pape 2011",
#  235: "Le P'tit Paysan Le P'tit Pape 2013",
#  236: "Le P'tit Paysan Le P'tit Pape 2012",
#  237: "Le P'tit Paysan Le P'tit Pape 2014",
#  238: "Le P'tit Paysan Le P'tit Pape 2015",
#  239: "Le P'tit Paysan Le P'tit Pape 2016",
#  240: "Le P'tit Paysan Le P'tit Pape 2017",
#  241: "Le P'tit Paysan Petite Sirah 2011",
#  242: "Le P'tit Paysan Petite Sirah 2013",
#  243: "Le P'tit Paysan Rose 2018",
#  244: 'Le Ragnaie Brunello di Montalcino 2010',
#  245: 'Le Ragose Amarone Della Valpolicella 2004',
#  246: 'Le Ragose Amarone Della Valpolicella 2005',
#  247: 'Le Roi des Pierres Sancerre 2014',
#  248: 'Le Roi des Pierres Sancerre 2015',
#  249: 'Le Roi des Pierres Sancerre 2016',
#  250: 'Le Roi des Pierres Sancerre Rose 2016',
#  251: 'Le Salette Amarone Classico 2011',
#  252: 'Le Salette Amarone Classico 2012',
#  253: 'Le Salette Amarone Classico 2013',
#  254: 'Le Salette Amarone della Valpolicella Pergole Vece Recioto (500ML) 2011',
#  255: 'Le Salette La Marega Amarone 2011',
#  256: 'Le Salette La Marega Amarone 2012',
#  257: 'Le Salette La Marega Amarone 2013',
#  258: 'Le Salette Pergole Vece Amarone 2008',
#  259: 'Le Salette Pergole Vece Amarone 2011',
#  260: 'Le Salette Pergole Vece Amarone 2012',
#  261: 'Le Salette Pergole Vece Amarone 2015',
#  262: 'Le Salette Valpolicella Classico 2012',
#  263: 'Le Terrazze Rosso Conero 2009',
#  264: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2003',
#  265: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2005',
#  266: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2012',
#  267: 'Le Vieux Donjon Chateauneuf-du-Pape (1.5 Liter Magnum) 2015',
#  268: 'Le Vieux Donjon Chateauneuf-du-Pape 2001',
#  269: 'Le Vieux Donjon Chateauneuf-du-Pape 2003',
#  270: 'Le Vieux Donjon Chateauneuf-du-Pape 2006',
#  271: 'Le Vieux Donjon Chateauneuf-du-Pape 2007',
#  272: 'Le Vieux Donjon Chateauneuf-du-Pape 2012',
#  273: 'Le Vieux Donjon Chateauneuf-du-Pape 2013',
#  274: 'Le Vieux Donjon Chateauneuf-du-Pape 2016',
#  275: 'Le Vieux Donjon Chateauneuf-du-Pape (375ML half-bottle) 2006',
#  276: 'Le Vieux Donjon Chateauneuf-du-Pape (375ML half-bottle) 2012',
#  277: 'Le Vieux Donjon Chateauneuf-du-Pape Blanc 2006',
#  278: 'Le Vigne di Eli Etna Bianco 2012',
#  279: 'Le Vigne di Eli Etna Rosso 2012',
#  280: 'Le Vigne di Eli Moganazzi-Volta Sciara Etna Rosso 2014',
#  281: 'Le Vigne di Eli Moganazzi-Volta Sciara Etna Rosso 2016',
#  282: 'Le Vigne Winery Paso Robles Cabernet Sauvignon 2016',
#  283: 'Lea Wines Sta. Rita Hills Pinot Noir 2013',
#  284: 'Lea Wines Sta. Rita Hills Pinot Noir 2014',
#  285: "Leacock's 10 Year Bual Madiera",
#  286: "Leacock's Bual 1966",
#  287: "Leacock's Rainwater Madeira",
#  288: 'Leaping Lizard Cabernet Sauvignon 2007',
#  289: 'Leasingham Bin 61 Shiraz 1997',
#  290: 'Leasingham Bin 61 Shiraz 1999',
#  291: 'Leasingham Bin 61 Shiraz 2001',
#  292: 'Leasingham Bin 61 Shiraz 2002',
#  293: 'Leasingham Bin 61 Shiraz 2000',
#  294: 'Leasingham Bin 61 Shiraz 1998',
#  295: 'Leasingham Bin 7 Riesling 2001',
#  296: 'Leasingham Bin 7 Riesling 2003',
#  297: 'Leasingham Bin 7 Riesling 2004',
#  298: 'Leasingham Bin 7 Riesling 2005',
#  299: 'Leasingham Clare Classic Cabernet Sauvignon 1997',
#  300: 'Leasingham Clare Classic Shiraz 1997',
#  301: 'Leasingham Clare Classic Shiraz 1998',
#  302: 'Leasingham Clare Classic Shiraz 2001',
#  303: 'Leasingham Clare Valley Bin 56 Cabernet Sauvignon 1999',
#  304: 'Leasingham Magnus Riesling 2003',
#  305: 'Leasingham Magnus Riesling 2006',
#  306: 'Leasingham Magnus Riesling 2007',
#  307: 'Leasingham Magnus Riesling 2004',
#  308: 'Lecheneaut Gevrey-Chambertin 2015',
#  309: 'Lecheneaut Gevrey-Chambertin 2014',
#  310: 'Lecheneaut Morey-Saint-Denis 2012',
#  311: 'Lecheneaut Morey-Saint-Denis 2016',
#  312: 'Lecheneaut Morey-St-Denis 2014',
#  313: 'Lecheneaut Morey-St-Denis 2015',
#  314: 'Lecheneaut Nuits-St. Georges 2014',
#  315: 'Lecheneaut Nuits-St. Georges 2015',
#  316: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2011',
#  317: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2014',
#  318: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2015',
#  319: 'Lecheneaut Nuits-St. Georges Damodes Premier Cru 2016',
#  320: 'Lecheneaut Nuits-St-Georges Les Pruliers Premier Cru 2015',
#  321: "L'Ecole 41 Barrel Fermented Semillon 2002",
#  322: "L'Ecole 41 Barrel Fermented Semillon 2004",
#  323: "L'Ecole 41 Chardonnay 2004",
#  324: "L'Ecole 41 Chardonnay 2006",
#  325: "L'Ecole 41 Chardonnay 2005",
#  326: "L'Ecole 41 Chardonnay 2008",
#  327: "L'Ecole 41 Chardonnay 2009",
#  328: "L'Ecole 41 Chardonnay 2007",
#  329: "L'Ecole 41 Chardonnay 2012",
#  330: "L'Ecole 41 Chardonnay 2013",
#  331: "L'Ecole 41 Chardonnay 2014",
#  332: "L'Ecole 41 Chardonnay 2015",
#  333: "L'Ecole 41 Chardonnay 2016",
#  334: "L'Ecole 41 Chardonnay 2018",
#  335: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2007",
#  336: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2011",
#  337: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2012",
#  338: "L'Ecole 41 Columbia Valley Cabernet Sauvignon 2015",
#  339: "L'Ecole 41 Columbia Valley Merlot 2000",
#  340: "L'Ecole 41 Columbia Valley Merlot 2003",
#  341: "L'Ecole 41 Columbia Valley Merlot 2004",
#  342: "L'Ecole 41 Columbia Valley Merlot 2005",
#  343: "L'Ecole 41 Columbia Valley Merlot 2006",
#  344: "L'Ecole 41 Columbia Valley Merlot 2007",
#  345: "L'Ecole 41 Columbia Valley Merlot 2010",
#  346: "L'Ecole 41 Columbia Valley Merlot 2011",
#  347: "L'Ecole 41 Columbia Valley Merlot 2012",
#  348: "L'Ecole 41 Columbia Valley Merlot 2013",
#  349: "L'Ecole 41 Columbia Valley Merlot 2008",
#  350: "L'Ecole 41 Columbia Valley Merlot 2014",
#  351: "L'Ecole 41 Columbia Valley Merlot 2016",
#  352: "L'Ecole 41 Columbia Valley Syrah 2012",
#  353: "L'Ecole 41 Columbia Valley Syrah 2014",
#  354: "L'Ecole 41 Columbia Valley Syrah 2013",
#  355: "L'Ecole 41 Columbia Valley Syrah 2015",
#  356: "L'Ecole 41 Columbia Valley Syrah 2016",
#  357: "L'Ecole 41 Ferguson Estate Red 2012",
#  358: "L'Ecole 41 Ferguson Estate Red 2013",
#  359: "L'Ecole 41 Ferguson Estate Red 2014",
#  360: "L'Ecole 41 Ferguson Estate Red 2017",
#  361: "L'Ecole 41 Fries Vineyard Semillon 2002",
#  362: "L'Ecole 41 Fries Vineyard Semillon 2003",
#  363: "L'Ecole 41 Luminesce Seven Hills Vineyard 2007",
#  364: "L'Ecole 41 Luminesce Seven Hills Vineyard 2008",
#  365: "L'Ecole 41 Luminesce Seven Hills Vineyard 2009",
#  366: "L'Ecole 41 Luminesce Seven Hills Vineyard 2010",
#  367: "L'Ecole 41 Luminesce Seven Hills Vineyard 2012",
#  368: "L'Ecole 41 Luminesce Seven Hills Vineyard 2011",
#  369: "L'Ecole 41 Luminesce Seven Hills Vineyard 2013",
#  370: "L'Ecole 41 Luminesce Seven Hills Vineyard 2014",
#  371: "L'Ecole 41 Luminesce Seven Hills Vineyard 2016",
#  372: "L'Ecole 41 Old Vines Chenin Blanc 2011",
#  373: "L'Ecole 41 Old Vines Chenin Blanc 2010",
#  374: "L'Ecole 41 Old Vines Chenin Blanc 2014",
#  375: "L'Ecole 41 Old Vines Chenin Blanc 2013",
#  376: "L'Ecole 41 Old Vines Chenin Blanc 2012",
#  377: "L'Ecole 41 Old Vines Chenin Blanc 2015",
#  378: "L'Ecole 41 Old Vines Chenin Blanc 2016",
#  379: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2001",
#  380: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2006",
#  381: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2008",
#  382: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2007",
#  383: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2012",
#  384: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2013",
#  385: "L'Ecole 41 Pepper Bridge Vineyard Apogee 2014",
#  386: "L'Ecole 41 Semillon 2005",
#  387: "L'Ecole 41 Semillon 2006",
#  388: "L'Ecole 41 Semillon 2007",
#  389: "L'Ecole 41 Semillon 2008",
#  390: "L'Ecole 41 Semillon 2010",
#  391: "L'Ecole 41 Semillon 2009",
#  392: "L'Ecole 41 Semillon 2012",
#  393: "L'Ecole 41 Semillon 2013",
#  394: "L'Ecole 41 Semillon 2015",
#  395: "L'Ecole 41 Semillon 2018",
#  396: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2001",
#  397: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2011",
#  398: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2014",
#  399: "L'Ecole 41 Seven Hills Vineyard Estate Syrah 2015",
#  400: "L'Ecole 41 Seven Hills Vineyard Merlot 2000",
#  401: "L'Ecole 41 Seven Hills Vineyard Merlot 2001",
#  402: "L'Ecole 41 Seven Hills Vineyard Merlot 2000",
#  403: "L'Ecole 41 Seven Hills Vineyard Merlot 2002",
#  404: "L'Ecole 41 Seven Hills Vineyard Merlot 2005",
#  405: "L'Ecole 41 Seven Hills Vineyard Merlot 2007",
#  406: "L'Ecole 41 Seven Hills Vineyard Perigee 2002",
#  407: "L'Ecole 41 Seven Hills Vineyard Perigee 2007",
#  408: "L'Ecole 41 Seven Hills Vineyard Perigee 2011",
#  409: "L'Ecole 41 Seven Hills Vineyard Perigee 2012",
#  410: "L'Ecole 41 Seven Hills Vineyard Perigee 2014",
#  411: "L'Ecole 41 Seven Hills Vineyard Perigee 2015",
#  412: "L'Ecole 41 Seven Hills Vineyard Perigee 2013",
#  413: "L'Ecole 41 Walla Voila Chenin Blanc 2009",
#  414: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 1998",
#  415: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2000",
#  416: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2001",
#  417: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2007",
#  418: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2009",
#  419: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2010",
#  420: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2011",
#  421: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2012",
#  422: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2013",
#  423: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2014",
#  424: "L'Ecole 41 Walla Walla Valley Cabernet Sauvignon 2016",
#  425: "L'Ecole 41 Walla Walla Valley Syrah 2003",
#  426: "L'Ecole 41 Walla Walla Valley Syrah 2004",
#  427: 'Ledge Catacombs Red Blend 2011',
#  428: 'Ledge Vineyard Drive Red Blend 2012',
#  429: 'Leese-Fitch Cabernet Sauvignon 2015',
#  430: 'Leese-Fitch Cabernet Sauvignon 2016',
#  431: 'Leese-Fitch Chardonnay 2015',
#  432: 'Leese-Fitch Chardonnay 2016',
#  433: 'Leese-Fitch Chardonnay 2017',
#  434: 'Leese-Fitch Pinot Noir 2016',
#  435: 'Leese-Fitch Sauvignon Blanc 2010',
#  436: 'Leese-Fitch Sauvignon Blanc 2015',
#  437: 'Leese-Fitch Sauvignon Blanc 2017',
#  438: 'Leese-Fitch Zinfandel 2016',
#  439: 'Leeuwin Estate Art Series Cabernet Sauvignon 1997',
#  440: 'Leeuwin Estate Art Series Cabernet Sauvignon 1998',
#  441: 'Leeuwin Estate Art Series Cabernet Sauvignon 1999',
#  442: 'Leeuwin Estate Art Series Cabernet Sauvignon 2001',
#  443: 'Leeuwin Estate Art Series Cabernet Sauvignon 2002',
#  444: 'Leeuwin Estate Art Series Cabernet Sauvignon 2003',
#  445: 'Leeuwin Estate Art Series Cabernet Sauvignon 2005',
#  446: 'Leeuwin Estate Art Series Cabernet Sauvignon 2006',
#  447: 'Leeuwin Estate Art Series Cabernet Sauvignon 2007',
#  448: 'Leeuwin Estate Art Series Cabernet Sauvignon 2008',
#  449: 'Leeuwin Estate Art Series Cabernet Sauvignon 2009',
#  450: 'Leeuwin Estate Art Series Cabernet Sauvignon 2010',
#  451: 'Leeuwin Estate Art Series Cabernet Sauvignon 2011',
#  452: 'Leeuwin Estate Art Series Cabernet Sauvignon 2013',
#  453: 'Leeuwin Estate Art Series Cabernet Sauvignon 2012',
#  454: 'Leeuwin Estate Art Series Cabernet Sauvignon 2015',
#  455: 'Leeuwin Estate Art Series Chardonnay 1998',
#  456: 'Leeuwin Estate Art Series Chardonnay 2000',
#  457: 'Leeuwin Estate Art Series Chardonnay 1999',
#  458: 'Leeuwin Estate Art Series Chardonnay 2002',
#  459: 'Leeuwin Estate Art Series Chardonnay 2003',
#  460: 'Leeuwin Estate Art Series Chardonnay 2004',
#  461: 'Leeuwin Estate Art Series Chardonnay 2001',
#  462: 'Leeuwin Estate Art Series Chardonnay 2005',
#  463: 'Leeuwin Estate Art Series Chardonnay 2006',
#  464: 'Leeuwin Estate Art Series Chardonnay 2007',
#  465: 'Leeuwin Estate Art Series Chardonnay 2010',
#  466: 'Leeuwin Estate Art Series Chardonnay 2011',
#  467: 'Leeuwin Estate Art Series Chardonnay 2013',
#  468: 'Leeuwin Estate Art Series Chardonnay 2009',
#  469: 'Leeuwin Estate Art Series Chardonnay 2012',
#  470: 'Leeuwin Estate Art Series Chardonnay 2014',
#  471: 'Leeuwin Estate Art Series Chardonnay 2008',
#  472: 'Leeuwin Estate Art Series Riesling 2001',
#  473: 'Leeuwin Estate Art Series Riesling 2006',
#  474: 'Leeuwin Estate Art Series Riesling 2004',
#  475: 'Leeuwin Estate Art Series Riesling 2008',
#  476: 'Leeuwin Estate Art Series Riesling 2010',
#  477: 'Leeuwin Estate Art Series Riesling 2002',
#  478: 'Leeuwin Estate Art Series Riesling 2011',
#  479: 'Leeuwin Estate Art Series Riesling 2012',
#  480: 'Leeuwin Estate Art Series Riesling 2013',
#  481: 'Leeuwin Estate Art Series Riesling 2014',
#  482: 'Leeuwin Estate Art Series Riesling 2015',
#  483: 'Leeuwin Estate Art Series Shiraz 1999',
#  484: 'Leeuwin Estate Art Series Shiraz 2000',
#  485: 'Leeuwin Estate Art Series Shiraz 2007',
#  486: 'Leeuwin Estate Art Series Shiraz 2009',
#  487: 'Leeuwin Estate Art Series Shiraz 2010',
#  488: 'Leeuwin Estate Art Series Shiraz 2012',
#  489: 'Leeuwin Estate Art Series Shiraz 2011',
#  490: 'Leeuwin Estate Art Series Shiraz 2013',
#  491: 'Leeuwin Estate Art Series Shiraz 2014',
#  492: 'Leeuwin Estate Margaret River Riesling 2000',
#  493: 'Leeuwin Estate Margaret River Riesling 1999',
#  494: 'Leeuwin Estate Prelude Cabernet Merlot (stained label) 1997',
#  495: 'Leeuwin Estate Prelude Vineyards Cabernet Sauvignon 2013',
#  496: 'Leeuwin Estate Prelude Vineyards Cabernet Sauvignon 2014',
#  497: 'Leeuwin Estate Prelude Vineyards Chardonnay 2001',
#  498: 'Leeuwin Estate Prelude Vineyards Chardonnay 2000',
#  499: 'Leeuwin Estate Prelude Vineyards Chardonnay 2004',
#  500: 'Leeuwin Estate Prelude Vineyards Chardonnay 2003',
#  501: 'Leeuwin Estate Prelude Vineyards Chardonnay 2006',
#  502: 'Leeuwin Estate Prelude Vineyards Chardonnay 2007',
#  503: 'Leeuwin Estate Prelude Vineyards Chardonnay 1999',
#  504: 'Leeuwin Estate Prelude Vineyards Chardonnay 2009',
#  505: 'Leeuwin Estate Prelude Vineyards Chardonnay 2010',
#  506: 'Leeuwin Estate Prelude Vineyards Chardonnay 2011',
#  507: 'Leeuwin Estate Prelude Vineyards Chardonnay 2012',
#  508: 'Leeuwin Estate Prelude Vineyards Chardonnay 2013',
#  509: 'Leeuwin Estate Prelude Vineyards Chardonnay 2014',
#  510: 'Leeuwin Estate Prelude Vineyards Chardonnay 2015',
#  511: 'Leeuwin Estate Prelude Vineyards Chardonnay 2018',
#  512: 'Leeuwin Estate Prelude Vineyards Chardonnay 2016',
#  513: 'Leeuwin Estate Siblings Sauvignon Blanc 2018',
#  514: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 1999',
#  515: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2002',
#  516: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2004',
#  517: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2011',
#  518: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2014',
#  519: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2015',
#  520: 'Leeuwin Estate Siblings Sauvignon Blanc Semillon 2016',
#  521: 'Leeuwin Estate Siblings Shiraz 2003',
#  522: 'Leeuwin Estate Siblings Shiraz 2007',
#  523: 'Leeuwin Estate Siblings Shiraz 2004',
#  524: 'Leeuwin Estate Siblings Shiraz 2012',
#  525: 'Leeuwin Estate Siblings Shiraz 2014',
#  526: 'Leeuwin Estate Siblings Shiraz 2013',
#  527: "Left Coast Cellars Cali's Cuvee Pinot Noir 2006",
#  528: "Left Coast Cellars Cali's Cuvee Pinot Noir 2013",
#  529: "Left Coast Cellars Cali's Cuvee Pinot Noir 2014",
#  530: "Left Coast Cellars Cali's Cuvee Pinot Noir 2016",
#  531: 'Left Coast Cellars Latitude 45 Pinot Noir 2014',
#  532: 'Left Coast Cellars The Orchards Pinot Gris 2009',
#  533: 'Legacy Red 2013',
#  534: 'Legaris Crianza 2005',
#  535: 'Legaris Crianza 2009',
#  536: 'Legaris Crianza 2010',
#  537: 'Legaris Crianza 2012',
#  538: 'Lemelson Chardonnay Reserve 2012',
#  539: 'Lemelson Dry Riesling 2008',
#  540: 'Lemelson Dry Riesling 2009',
#  541: 'Lemelson Dry Riesling 2012',
#  542: 'Lemelson Jerome Reserve Pinot Noir 2012',
#  543: 'Lemelson Dry Riesling 2015',
#  544: 'Lemelson Meyer Vineyard Pinot Noir 2012',
#  545: 'Lemelson Meyer Vineyard Pinot Noir 2015',
#  546: 'Lemelson Stermer Vineyard Pinot Noir 2014',
#  547: "Lemelson Thea's Select Pinot Noir 2000",
#  548: "Lemelson Thea's Select Pinot Noir 2006",
#  549: "Lemelson Thea's Select Pinot Noir 2012",
#  550: "Lemelson Thea's Select Pinot Noir 2014",
#  551: "Lemelson Thea's Select Pinot Noir 2015",
#  552: 'Lengs and Cooter Shiraz The Victor 2005',
#  553: 'Lengs and Cooter Shiraz The Victor 2006',
#  554: 'Lengs and Cooter The Victor 2002',
#  555: 'Leo Steen Ascona Vineyard Cabernet Franc 2017',
#  556: 'Leo Steen Jurassic Vineyard Chenin Blanc 2012',
#  557: 'Leo Steen Jurassic Vineyard Chenin Blanc 2013',
#  558: 'Leo Steen Chardonnay 2015',
#  559: 'Leo Steen Jurassic Vineyard Chenin Blanc 2015',
#  560: 'Leo Steen Jurassic Vineyard Chenin Blanc 2016',
#  561: 'Leo Steen Peaberry Chenin Blanc 2016',
#  562: 'Leo Steen Provisor Vineyard Grenache 2016',
#  563: 'Leo Steen Provisor Vineyard Grenache 2015',
#  564: 'Leo Steen Saini Vineyard Chenin Blanc 2015',
#  565: 'Leo Steen Saini Vineyard Chenin Blanc 2016',
#  566: 'Leo Steen Scala Vineyard Syrah 2013',
#  567: 'Leone de Castris Primitivo di Manduria Villa Santera 2009',
#  568: 'Leone de Castris Salice Salentino Riserva 2006',
#  569: 'Leone de Castris Salice Salentino Riserva 2007',
#  570: 'Leone de Castris Salice Salentino Riserva 2010',
#  571: 'Leone de Castris Salice Salentino Riserva 2011',
#  572: 'Leone de Castris Salice Salentino Riserva 2014',
#  573: 'Leone de Castris Salice Salentino Riserva 2015',
#  574: 'Leonetti Cabernet Sauvignon (1.5 Liter Magnum) 2014',
#  575: 'Leone de Castris Verdeca Bianco Messapia 2009',
#  576: 'Leonetti Cabernet Sauvignon 1994',
#  577: 'Leonetti Cabernet Sauvignon 1995',
#  578: 'Leonetti Cabernet Sauvignon 1997',
#  579: 'Leonetti Cabernet Sauvignon 1998',
#  580: 'Leonetti Cabernet Sauvignon 2001',
#  581: 'Leonetti Cabernet Sauvignon 2000',
#  582: 'Leonetti Cabernet Sauvignon 2005',
#  583: 'Leonetti Cabernet Sauvignon 2010',
#  584: 'Leonetti Cabernet Sauvignon 2011',
#  585: 'Leonetti Cabernet Sauvignon 2012',
#  586: 'Leonetti Cabernet Sauvignon 2013',
#  587: 'Leonetti Cabernet Sauvignon 2014',
#  588: 'Leonetti Cabernet Sauvignon 2015',
#  589: 'Leonetti Cabernet Sauvignon (damaged label) 2007',
#  590: 'Leonetti Cabernet Sauvignon (damaged label) 2009',
#  591: 'Leonetti Merlot 1993',
#  592: 'Leonetti Merlot 1995',
#  593: 'Leonetti Merlot 1997',
#  594: 'Leonetti Merlot 1998',
#  595: 'Leonetti Merlot 1999',
#  596: 'Leonetti Merlot 2001',
#  597: 'Leonetti Merlot 2003',
#  598: 'Leonetti Merlot 2004',
#  599: 'Leonetti Merlot 2005',
#  600: 'Leonetti Merlot 2007',
#  601: 'Leonetti Merlot 2006',
#  602: 'Leonetti Merlot 2008',
#  603: 'Leonetti Merlot 2012',
#  604: 'Leonetti Merlot 2010',
#  605: 'Leonetti Merlot 2013',
#  606: 'Leonetti Merlot 2015',
#  607: 'Leonetti Merlot 2014',
#  608: 'Leonetti Merlot 2016',
#  609: 'Leonetti Merlot (loose foil capsule) 2000',
#  610: 'Leonetti Merlot (scuffed labels) 2011',
#  611: 'Leonetti Reserve 1998',
#  612: 'Leonetti Reserve 2002',
#  613: 'Leonetti Reserve 2005',
#  614: 'Leonetti Reserve 2000',
#  615: 'Leonetti Reserve 2006',
#  616: 'Leonetti Reserve 2011',
#  617: 'Leonetti Reserve 2012',
#  618: 'Leonetti Reserve 2014',
#  619: 'Leonetti Reserve 2013',
#  620: 'Leonetti Reserve 2015',
#  621: 'Leonetti Reserve (torn label) 2007',
#  622: 'Leonetti Reserve (torn label) 2008',
#  623: 'Leonetti Sangiovese 2005',
#  624: 'Leonetti Sangiovese 2000',
#  625: 'Leonetti Sangiovese 2006',
#  626: 'Leonetti Sangiovese 2007',
#  627: 'Leonetti Sangiovese 2008',
#  628: 'Leonetti Sangiovese 2009',
#  629: 'Leonetti Sangiovese 2011',
#  630: 'Leonetti Sangiovese 2010',
#  631: 'Leonetti Sangiovese 2013',
#  632: 'Leonetti Sangiovese 2012',
#  633: 'Leonetti Sangiovese 2014',
#  634: 'Leonetti Seven Hills Vineyard Reserve Cabernet Sauvignon 1996',
#  635: 'Les Alexandrins Cornas 2016',
#  636: 'Les Alexandrins Domaine Crozes-Hermitage 2016',
#  637: 'Les Alexandrins Domaine Saint-Joseph 2015',
#  638: 'Les Alexandrins Domaine Saint-Joseph 2016',
#  639: 'Les Alexandrins Maison Crozes-Hermitage 2016',
#  640: 'Les Alexandrins Syrah 2018',
#  641: "Les Alexandrins Terrasses de l'Eridan Cotes du Rhone Blanc 2017",
#  642: "Les Alexandrins Terrasses de l'Eridan Cotes du Rhone Rouge 2017",
#  643: 'Les Asteries 2005',
#  644: 'Les Asteries 2007',
#  645: 'Les Asteries 2008',
#  646: 'Les Asteries 2009',
#  647: 'Les Asteries 2011',
#  648: 'Les Asteries 2010',
#  649: "Les Clefs d'Or Les Craus Centenaires 2015",
#  650: "Les Clefs d'Or Les Craus Centenaires 2009",
#  651: "Les Clefs d'Or Les Craus Centenaires 2010",
#  652: 'Les Cretes Coteau La Tour 2008',
#  653: 'Les Cretes Le Sommet Nebbiolo 2016',
#  654: 'Les Cretes Les Abeilles 2006',
#  655: "Les Cretes Valle d'Aosta Chardonnay 2010",
#  656: "Les Cretes Valle d'Aosta Cuvee Bois Chardonnay 2016",
#  657: 'Les Forts de Latour 1996',
#  658: 'Les Forts de Latour 1999',
#  659: 'Les Forts de Latour 2000',
#  660: 'Les Forts de Latour 2001',
#  661: 'Les Forts de Latour 2005',
#  662: 'Les Forts de Latour 2008',
#  663: 'Les Forts de Latour 2009',
#  664: 'Les Garrigues Cotes du Rhone 2017',
#  665: 'Les Halos de Jupiter Chateauneuf-du-Pape 2009',
#  666: 'Les Halos de Jupiter Chateauneuf-du-Pape Adrastee 2009',
#  667: 'Les Halos de Jupiter Cotes du Rhone 2010',
#  668: 'Les Hauts de Lagarde Bordeaux Blanc 2013',
#  669: "Les Quatre Tours Coteaux d'Aix en Provence 2016",
#  670: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2008",
#  671: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2009",
#  672: 'Les Vignerons de Tautavel Cotes du Roussillon Villages Tautavel Silex 2012',
#  673: "Les Vignerons d'Estezargues La Granacha Cotes du Rhone Villages Signargues 2007",
#  674: "Les Vins Breban L'Opale de La Presqu'ile de St-Tropez Provence 2012",
#  675: 'Les Vignes Oubliées Coteaux du Languedoc Terrasses du Larzac 2014',
#  676: "L'Esprit de Chevalier Pessac Leognan 2000",
#  677: 'Leth Steinagrund Gruner Veltliner 2007',
#  678: 'Leth Steinagrund Gruner Veltliner 2008',
#  679: 'Leth Steinagrund Gruner Veltliner 2010',
#  680: 'Leth Steinagrund Gruner Veltliner 2012',
#  681: 'Leth Steinagrund Gruner Veltliner 2015',
#  682: 'Leth Steinagrund Gruner Veltliner 2016',
#  683: 'Leth Steinagrund Gruner Veltliner 2017',
#  684: 'Levendi River South Ranch Pinot Noir 2013',
#  685: 'Levendi Stagecoach Cabernet Sauvignon 2008',
#  686: 'Levendi Sweeney Ranch Chardonnay 2010',
#  687: 'Levet La Chavaroche Cote Rotie 2013',
#  688: 'Levet Les Journaries Cote Rotie 2010',
#  689: 'Leviathan (1.5 Liter Magnum) 2016',
#  690: 'Leviathan 2010',
#  691: 'Leviathan 2011',
#  692: 'Levy & McClellan Proprietary Red 2004',
#  693: 'Levy & McClellan Proprietary Red 2005',
#  694: 'Lewelling Cabernet Sauvignon 2000',
#  695: 'Lewelling Cabernet Sauvignon 2005',
#  696: 'Lewelling Cabernet Sauvignon 2001',
#  697: 'Lewelling Cabernet Sauvignon 2006',
#  698: 'Lewelling Cabernet Sauvignon 2007',
#  699: 'Lewelling Cabernet Sauvignon 2009',
#  700: 'Lewelling Cabernet Sauvignon 2010',
#  701: 'Lewelling Cabernet Sauvignon 2012',
#  702: 'Lewelling Wight Vineyard Cabernet Sauvignon 2003',
#  703: 'Lewelling Wight Vineyard Cabernet Sauvignon 2005',
#  704: 'Lewelling Wight Vineyard Cabernet Sauvignon 2006',
#  705: 'Lewelling Wight Vineyard Cabernet Sauvignon 2009',
#  706: 'Lewelling Wight Vineyard Cabernet Sauvignon 2008',
#  707: 'Lewelling Wight Vineyard Cabernet Sauvignon 2007',
#  708: 'Lewelling Wight Vineyard Cabernet Sauvignon 2010',
#  709: "Lewis Cellars Alec's Blend Red 2002",
#  710: "Lewis Cellars Alec's Blend Red 2003",
#  711: "Lewis Cellars Alec's Blend Red 2007",
#  712: "Lewis Cellars Alec's Blend Red 2009",
#  713: "Lewis Cellars Alec's Blend Red 2005",
#  714: "Lewis Cellars Alec's Blend Red 2010",
#  715: "Lewis Cellars Alec's Blend Red 2014",
#  716: "Lewis Cellars Alec's Blend Red 2013",
#  717: "Lewis Cellars Alec's Blend Red 2017",
#  718: 'Lewis Cellars Barcaglia Lane Chardonnay 2006',
#  719: 'Lewis Cellars Barcaglia Lane Chardonnay 2008',
#  720: 'Lewis Cellars Barcaglia Lane Chardonnay 2009',
#  721: 'Lewis Cellars Barcaglia Lane Chardonnay 2015',
#  722: 'Lewis Cellars Barcaglia Lane Chardonnay 2014',
#  723: 'Lewis Cellars Barcaglia Lane Chardonnay 2017',
#  724: 'Lewis Cellars Cabernet Sauvignon 2002',
#  725: 'Lewis Cellars Cabernet Sauvignon 2004',
#  726: 'Lewis Cellars Cabernet Sauvignon 2005',
#  727: 'Lewis Cellars Cabernet Sauvignon 2012',
#  728: 'Lewis Cellars Cabernet Sauvignon 2015',
#  729: 'Lewis Cellars Cabernet Sauvignon 2014',
#  730: 'Lewis Cellars Cabernet Sauvignon 2013',
#  731: 'Lewis Cellars Cabernet Sauvignon 2017',
#  732: 'Lewis Cellars Cuvee L 2005',
#  733: 'Lewis Cellars Cuvee L 2006',
#  734: 'Lewis Cellars Cuvee L Cabernet Sauvignon 2014',
#  735: 'Lewis Cellars Cuvee L Cabernet Sauvignon 2015',
#  736: 'Lewis Cellars Hillstone Vineyard Cabernet Sauvignon 2014',
#  737: 'Lewis Cellars Hudson Vineyards Syrah 2006',
#  738: "Lewis Cellars Mason's Cabernet Sauvignon 2003",
#  739: "Lewis Cellars Mason's Cabernet Sauvignon 2015",
#  740: "Lewis Cellars Mason's Cabernet Sauvignon 2018",
#  741: 'Lewis Cellars Merlot 2000',
#  742: 'Lewis Cellars Napa Valley Chardonnay 2008',
#  743: 'Lewis Cellars Napa Valley Chardonnay 2015',
#  744: 'Lewis Cellars Napa Valley Chardonnay 2014',
#  745: 'Lewis Cellars Napa Valley Chardonnay 2016',
#  746: 'Lewis Cellars Napa Valley Syrah 2006',
#  747: 'Lewis Cellars Napa Valley Syrah 2007',
#  748: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2011',
#  749: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5 Liter Magnum) 2016',
#  750: 'Lewis Cellars Reserve Cabernet Sauvignon (1.5L Magnum) 2004',
#  751: 'Lewis Cellars Reserve Cabernet Sauvignon 1995',
#  752: 'Lewis Cellars Reserve Cabernet Sauvignon 2000',
#  753: 'Lewis Cellars Reserve Cabernet Sauvignon 2005',
#  754: 'Lewis Cellars Reserve Cabernet Sauvignon 2006',
#  755: 'Lewis Cellars Reserve Cabernet Sauvignon 2007',
#  756: 'Lewis Cellars Reserve Cabernet Sauvignon 2008',
#  757: 'Lewis Cellars Reserve Cabernet Sauvignon 2009',
#  758: 'Lewis Cellars Reserve Cabernet Sauvignon 2010',
#  759: 'Lewis Cellars Reserve Cabernet Sauvignon 2011',
#  760: 'Lewis Cellars Reserve Cabernet Sauvignon 2015',
#  761: 'Lewis Cellars Reserve Cabernet Sauvignon 2014',
#  762: 'Lewis Cellars Reserve Cabernet Sauvignon 2016',
#  763: 'Lewis Cellars Reserve Cabernet Sauvignon (scuffed labels) 2012',
#  764: 'Lewis Cellars Reserve Chardonnay 2008',
#  765: 'Lewis Cellars Reserve Chardonnay 2015',
#  766: 'Lewis Cellars Reserve Chardonnay 2018',
#  767: 'Lewis Cellars Reserve Chardonnay 2017',
#  768: 'Lewis Cellars Reserve Merlot 1995',
#  769: 'Lewis Cellars Sauvignon Blanc 2016',
#  770: 'Lewis Cellars Sauvignon Blanc 2018',
#  771: 'Lewis Cellars Sonoma Chardonnay 2014',
#  772: 'Lewis Cellars Sonoma Chardonnay 2015',
#  773: 'Lewis Cellars Sonoma Chardonnay 2017',
#  774: 'Lewis Cellars Sonoma Valley Chardonnay 2008',
#  775: "Lewis Cellars Syrah Ethan's Blend 2005",
#  776: "Lewis Cellars Syrah Ethan's Blend 2014",
#  777: "Lewis Cellars Syrah Ethan's Blend 2009",
#  778: 'Lexington Apex Red 2011',
#  779: 'Lexington Gist Ranch Cabernet Sauvignon 2011'}

# %%
# if you want to get the values of a row, you can use the index of the row as a key, but you have to use it for every column you need. For example:
print(dict_data['name'][0], # get the value of the 'name' column for the row with index 0
dict_data['rating'][0], # get the value of the 'rating' column for the row with index 0
dict_data['region'][0], # get the value of the 'region' column for the row with index 0
)
# Out:
# Laurenz V Charming Gruner Veltliner 2013 90.0 Kamptal, Austria

# %% [markdown]
# ## My Pandas Responses to the Tasks ##
#
# 1. Filter the dataframe to show us only Rose wines.
# 2. Convert it to a dictionary type using `df.to_dict()`.
# 3. Save the dictionary to a JSON file.
# 4. Go further and explore the data even more, seeing if there's any improvements that can be made on the dataset according to my own experience in the wine industry.

# %%
# We will use a boolean mask to filter our dataframe.

mask = df.variety.str.contains('Pink', na=False)
rose_wines = df[mask].to_dict(orient='records') 

# I used the `orient='records'` here in order to get the correct axis-orientation to match
# the output of the earlier JSON files we made. The dataframe's default orientation of the 
# dictionary was around the Index, otherwise.

# Write the list of dictionaries to a JSON file
with open('sample_data/rose_wines.json', 'w') as f:
    json.dump(rose_wines, f, sort_keys=True, indent=4)

# %%
# This is the start of my own work on this data.
# I love wine! I make my own wine, and I've worked in wine-related jobs 
# pretty consistently over the past 20 years, so I'm particularly interested in this data!
# First, I want to take another look at the head of the dataset. 

df.tail(5)
# Out:
#                                              name  grape  \
# 775        Lewis Cellars Syrah Ethan's Blend 2005    NaN
# 776        Lewis Cellars Syrah Ethan's Blend 2014    NaN
# 777        Lewis Cellars Syrah Ethan's Blend 2009    NaN
# 778                       Lexington Apex Red 2011    NaN
# 779  Lexington Gist Ranch Cabernet Sauvignon 2011    NaN
#
#                                region   variety  rating  \
# 775                        California  Red Wine    92.0
# 776                        California  Red Wine    93.0
# 777                        California  Red Wine    94.0
# 778  Santa Cruz Mountains, California  Red Wine    91.0
# 779  Santa Cruz Mountains, California  Red Wine    91.0
#
#                                                  notes
# 775  Now 7 years old, Alec's younger brother Ethan ...
# 776  Born in 2000, everything about Ethan and his n...
# 777  Positioned between brothers, Alec and Mason, E...
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot
# 779          Blend: 80% Cabernet Sauvignon, 20% Merlot

# %%
# There's actually some cleanup to do. Right away we see that the first 5 wines are Gruner Veltliner,
# which is a grape. But the grape varietal isn't listed under the grape column. I hope we aren't 
# going into a whole rabbit-hole of text analysis on the name column, but then again, if that's 
# what it takes, we are gonna do it. 
#
# Second, I'm not a fan of the column name 'variety', because of the similarity to the term 'varietal' 
# used to describe the name of the grape. (Gruner Veltliner is a varietal of the Vinus Vinifera species 
# of grape). So we are going to change 'variety' to 'styles', which is less confusing nomenclature.
# And we are going to look at the unique styles. Also note, I'm using the plural 'styles' here because
# of a Python function named 'style'. The .style() function gets in the way of calling the column by 
# dot-syntax like 'df.style.whatever()'. 

df.rename(columns={'variety':'styles'}, inplace=True)
unique_styles = df.styles.unique()
print(unique_styles)
# Out:
# ['White Wine' 'Red Wine' 'Sparkling & Champagne' 'Pink and Rosé' nan
#  'Collectible']

# %%
# Those are some superfluous names. And what does 'Collectible' even mean? 
# We are going to rename the first 4 unique styles to 'red', 'white', 'sparkling', and 'rose'. 

df.loc[df['styles'] == 'Red Wine', 'styles'] = 'red'
df.loc[df['styles'] == 'White Wine', 'styles'] = 'white'
df.loc[df['styles'] == 'Sparkling & Champagne', 'styles'] = 'sparkling'
df.loc[df['styles'] == 'Pink and Rosé', 'styles'] = 'rose'

# Then let's see what's in 'Collectible' and 'nan' to know what to do with those values.

style_mask = (df.loc[:,'styles'].isnull()) | (df.loc[:,'styles'] == 'Collectible')
df[style_mask]
# Out:
#                                                   name  grape  \
# 254  Le Salette Amarone della Valpolicella Pergole ...    NaN
# 285                     Leacock's 10 Year Bual Madiera    NaN
# 286                                Leacock's Bual 1966    NaN
# 287                        Leacock's Rainwater Madeira    NaN
#
#                           region       styles  rating  \
# 254  Valpolicella, Veneto, Italy          NaN    93.0
# 285                     Portugal          NaN    88.0
# 286                     Portugal  Collectible    92.0
# 287            Madeira, Portugal          NaN    90.0
#
#                                                  notes
# 254  Ruby red with cyclamen accents. Dry fruit, for...
# 285  Clear, amber colour with golden highlights. A ...
# 286  Clear, amber colour with golden highlights and...
# 287  Made from Tinta Negra Mole grapes collected fr...

# %%
# There's four wines we have style questions about. I did a little research to be certain of 'style' and to confirm 
# that Amarone is not fortified. We can accurately classify it as 'red' in terms of 'style'.
# The three Leacock's wines are all fortified Maderia wines from Portugal. 
#
# Let's change the Amarone to a 'red' and the Madieras to 'fortified'.

df.loc[254, 'styles'] = 'red'
df.loc[285:287, 'styles'] = 'fortified'
df[style_mask]
# Out:
#                                                   name  grape  \
# 254  Le Salette Amarone della Valpolicella Pergole ...    NaN
# 285                     Leacock's 10 Year Bual Madiera    NaN
# 286                                Leacock's Bual 1966    NaN
# 287                        Leacock's Rainwater Madeira    NaN
#
#                           region     styles  rating  \
# 254  Valpolicella, Veneto, Italy        red    93.0
# 285                     Portugal  fortified    88.0
# 286                     Portugal  fortified    92.0
# 287            Madeira, Portugal  fortified    90.0
#
#                                                  notes
# 254  Ruby red with cyclamen accents. Dry fruit, for...
# 285  Clear, amber colour with golden highlights. A ...
# 286  Clear, amber colour with golden highlights and...
# 287  Made from Tinta Negra Mole grapes collected fr...

# %%
# Let's check out the rest of the columns to look for complete/incomplete data.

df.name.head()
# df.grape.describe()
# df.styles.describe()
# df.region.describe()
# df.rating.describe()
# df.notes.describe()

# Theres a couple issues:
# 'name': 1 dupe row.
# 'grape': no values at all! We will have to do some parsing of the name column to get those grapes.
# 'styles': is good to go.
# 'region': we could be more granular with regional information by splitting country off to a new column
# we could also split subregions off for more useful granularity. 
# (example: split 'Valpolicela' into a subregion column from 'Valpolicela, Veneto' and leave
# Veneto as the main region and Italy as country) .
# Out:
# 0    Laurenz V Charming Gruner Veltliner 2013
# 1    Laurenz V Charming Gruner Veltliner 2014
# 2     Laurenz V Singing Gruner Veltliner 2007
# 3     Laurenz V Singing Gruner Veltliner 2010
# 4     Laurenz V Singing Gruner Veltliner 2011
# Name: name, dtype: object

# %%
# We can process this comprehensive list (scraped from "https://www.wineenthusiast.com/varietals/") into
# a Python list, and iterate through it over the name column (with a little regex help) in order to find 
# grape varietal matches within the wines' names. 

# My plan for turning this into a set:
# Start with the whole thing as a string.
# Convert any accented characters (diacritics) into their non-accented counterparts using unicode.
# Split the string by line breaks.
# Run a list comprehension on each line as a sublist of the main list, breaking up any line that has ' / '.
# Run a list comprehension to remove all items 1 character in length, in order to remove the single letters.

# %% [markdown]
# The string in question is declared into the variable 'grape_str' below, and the code cell is hidden because the string is super long and we don't need to scroll through it.

# %%
grape_str = '''A
Aglianico
Albana
Albariño / Alvarinho
Aleatico
Alfrocheiro
Alicante Bouschet
Aligoté
Altesse
Alvarelhão
Antão Vaz
Aragonês / Aragonez
Arinto
Arneis
Assyrtico / Assyrtiko
Auxerrois
Avesso
B
Baco Noir
Baga
Barbera
Bical
Black Muscat
Blanc du Bois
Blaufränkisch
Bobal
Bonarda
Bordeaux-style Red Blend
Bordeaux-style White Blend
Brachetto
Braucol
Bual
C
Cabernet Franc
Cabernet Sauvignon
Cannonau
Carignan / Carignano
Carmenère
Carricante
Casavecchia
Castelão
Catarratto
Cencibel
Cerceal
Chambourcin
Champagne Blend
Charbono
Chardonnay
Chasselas
Chenin Blanc
Ciliegiolo
Cinsault
Clairette
Claret
Coda di Volpe
Colombard
Cortese
Corvina
Counoise
D
Dolcetto
Dornfelder
Duras
Durif
E
Encruzado
F
Falanghina
Fer Servadou
Fernão Pires
Feteasca Neagra
Fiano
Frappato
Friulano
Fumé Blanc
Furmint
G
Gaglioppo
Gamay
Garganega
Gewürztraminer
Glera (Prosecco)
Godello
Graciano
Grauburgunder
Grecanico
Grechetto
Greco / Greco Bianco
Grenache Blanc / Garnacha Blanca
Grenache-Syrah-Mourvèdre
(G-S-M)
Grenache / Garnacha
Grillo
Gros Manseng
Grüner Veltliner
H
Hárslevelű
Hondarrabi Zuri
I
Inzolia / Insolia
J
Jacquère
Jaen
K
Kalecik Karasi
Kékfrankos
Kerner
L
Lagrein
Lambrusco
Lemberger
Loin de l'Oeil
Loureiro
M
Macabeo
Madeira Blend
Magliocco
Malagousia
Malbec
Malvasia
Mantonico
Manzoni
Marsanne
Marzemino
Mataro
Maturana
Mauzac
Mavrodaphne
Mavrud
Melon
Mencía
Meritage
Merlot
Mission
Molinara
Monastrell
Mondeuse
Monica
Montepulciano
Morillon
Moscadello
Moscatel
Moscatel Roxo
Moschofilero
Mourvèdre
Mtsvane
Müller-Thurgau
Muscadelle / Muscadel
Muscat / Moscato
N
Narince
Nascetta
Nebbiolo
Negrette
Negroamaro
Nerello Cappuccio
Nerello Mascalese
Nero d'Avola
Nero di Troia
Neuburger
Norton
Nosiola
Nuragus
O
Öküzgözü
Orange Muscat
P
Pallagrello
Palomino
Pansa Blanca
Passerina
Pecorino
Pedro Ximénez
Perricone
Petit Manseng
Petit Verdot
Petite Sirah
Picolit
Picpoul
Piedirosso
Pignoletto
Pinot Blanc / Pinot Bianco
Pinot Grigio / Pinot Gris
Pinot Meunier
Pinot Noir / Pinot Nero
Pinotage
Plavac Mali
Port
Posip
Prié Blanc
Prieto Picudo
Primitivo
Prugnolo Gentile
R
Raboso
Red Blend
Refosco
Rhône-Style Red Blend
Rhône-Style White Blend
Ribolla Gialla
Rieslaner
Riesling
Rivaner
Rkatsiteli
Robola
Roditis
Rolle
Rosé
Roter Veltliner
Rotgipfler
Roussanne
Ruché
S
Sagrantino
Sämling
Sangiovese
Saperavi
Sauvignon Blanc
Sauvignon Gris
Savagnin
Savatiano
Scheurebe
Schiava
Sémillon
Seyval Blanc
Sherry
Siria
Sousão
Sparkling Blend
Spätburgunder
St. Laurent
Susumaniello
Sylvaner / Silvaner
Symphony
Syrah / Shiraz
T
Tannat
Tempranillo
Tempranillo Blanco
Teran
Teroldego
Tinta de Toro
Tinta Fina / Tinto Fino
Tinta Roriz
Tinto del Pais
Tokaji / Tokay
Torrontés
Touriga Franca
Touriga Nacional
Traminer
Traminette
Trebbiano
Trepat
Trincadeira
Trousseau
Turbiana
U
Uva di Troia
V
Valdiguié
Verdeca
Verdejo
Verdelho
Verdicchio
Verduzzo Friulano / Verduzzo
Vermentino
Vernaccia
Vidal Blanc
Vignoles
Vilana
Viognier
Viura
Vranec
W
Weissburgunder
Welschriesling
White Blend
X
Xarel-lo
Xinomavro
Z
Zibibbo
Zierfandler
Zinfandel
Zweigelt
'''

# %%
# First we convert the string to NFD unicode. We can use the unicodedata library to do this.

import unicodedata

def remove_accents(input_str):
    # Normalize the string to 'NFD' form
    nfd_form = unicodedata.normalize('NFD', input_str)
    # Return the string with diacritics/accents removed
    return "".join([c for c in nfd_form if not unicodedata.combining(c)])


grape_str = remove_accents(grape_str)
grape_list = grape_str.split('\n')
grape_list = [item for sublist in [i.split(' / ') for i in grape_list] for item in sublist]
grape_list = [grape for grape in grape_list if len(grape) > 1]
grape_list
# Out:
# ['Aglianico',
#  'Albana',
#  'Albarino',
#  'Alvarinho',
#  'Aleatico',
#  'Alfrocheiro',
#  'Alicante Bouschet',
#  'Aligote',
#  'Altesse',
#  'Alvarelhao',
#  'Antao Vaz',
#  'Aragones',
#  'Aragonez',
#  'Arinto',
#  'Arneis',
#  'Assyrtico',
#  'Assyrtiko',
#  'Auxerrois',
#  'Avesso',
#  'Baco Noir',
#  'Baga',
#  'Barbera',
#  'Bical',
#  'Black Muscat',
#  'Blanc du Bois',
#  'Blaufrankisch',
#  'Bobal',
#  'Bonarda',
#  'Bordeaux-style Red Blend',
#  'Bordeaux-style White Blend',
#  'Brachetto',
#  'Braucol',
#  'Bual',
#  'Cabernet Franc',
#  'Cabernet Sauvignon',
#  'Cannonau',
#  'Carignan',
#  'Carignano',
#  'Carmenere',
#  'Carricante',
#  'Casavecchia',
#  'Castelao',
#  'Catarratto',
#  'Cencibel',
#  'Cerceal',
#  'Chambourcin',
#  'Champagne Blend',
#  'Charbono',
#  'Chardonnay',
#  'Chasselas',
#  'Chenin Blanc',
#  'Ciliegiolo',
#  'Cinsault',
#  'Clairette',
#  'Claret',
#  'Coda di Volpe',
#  'Colombard',
#  'Cortese',
#  'Corvina',
#  'Counoise',
#  'Dolcetto',
#  'Dornfelder',
#  'Duras',
#  'Durif',
#  'Encruzado',
#  'Falanghina',
#  'Fer Servadou',
#  'Fernao Pires',
#  'Feteasca Neagra',
#  'Fiano',
#  'Frappato',
#  'Friulano',
#  'Fume Blanc',
#  'Furmint',
#  'Gaglioppo',
#  'Gamay',
#  'Garganega',
#  'Gewurztraminer',
#  'Glera (Prosecco)',
#  'Godello',
#  'Graciano',
#  'Grauburgunder',
#  'Grecanico',
#  'Grechetto',
#  'Greco',
#  'Greco Bianco',
#  'Grenache Blanc',
#  'Garnacha Blanca',
#  'Grenache-Syrah-Mourvedre',
#  '(G-S-M)',
#  'Grenache',
#  'Garnacha',
#  'Grillo',
#  'Gros Manseng',
#  'Gruner Veltliner',
#  'Harslevelu',
#  'Hondarrabi Zuri',
#  'Inzolia',
#  'Insolia',
#  'Jacquere',
#  'Jaen',
#  'Kalecik Karasi',
#  'Kekfrankos',
#  'Kerner',
#  'Lagrein',
#  'Lambrusco',
#  'Lemberger',
#  "Loin de l'Oeil",
#  'Loureiro',
#  'Macabeo',
#  'Madeira Blend',
#  'Magliocco',
#  'Malagousia',
#  'Malbec',
#  'Malvasia',
#  'Mantonico',
#  'Manzoni',
#  'Marsanne',
#  'Marzemino',
#  'Mataro',
#  'Maturana',
#  'Mauzac',
#  'Mavrodaphne',
#  'Mavrud',
#  'Melon',
#  'Mencia',
#  'Meritage',
#  'Merlot',
#  'Mission',
#  'Molinara',
#  'Monastrell',
#  'Mondeuse',
#  'Monica',
#  'Montepulciano',
#  'Morillon',
#  'Moscadello',
#  'Moscatel',
#  'Moscatel Roxo',
#  'Moschofilero',
#  'Mourvedre',
#  'Mtsvane',
#  'Muller-Thurgau',
#  'Muscadelle',
#  'Muscadel',
#  'Muscat',
#  'Moscato',
#  'Narince',
#  'Nascetta',
#  'Nebbiolo',
#  'Negrette',
#  'Negroamaro',
#  'Nerello Cappuccio',
#  'Nerello Mascalese',
#  "Nero d'Avola",
#  'Nero di Troia',
#  'Neuburger',
#  'Norton',
#  'Nosiola',
#  'Nuragus',
#  'Okuzgozu',
#  'Orange Muscat',
#  'Pallagrello',
#  'Palomino',
#  'Pansa Blanca',
#  'Passerina',
#  'Pecorino',
#  'Pedro Ximenez',
#  'Perricone',
#  'Petit Manseng',
#  'Petit Verdot',
#  'Petite Sirah',
#  'Picolit',
#  'Picpoul',
#  'Piedirosso',
#  'Pignoletto',
#  'Pinot Blanc',
#  'Pinot Bianco',
#  'Pinot Grigio',
#  'Pinot Gris',
#  'Pinot Meunier',
#  'Pinot Noir',
#  'Pinot Nero',
#  'Pinotage',
#  'Plavac Mali',
#  'Port',
#  'Posip',
#  'Prie Blanc',
#  'Prieto Picudo',
#  'Primitivo',
#  'Prugnolo Gentile',
#  'Raboso',
#  'Red Blend',
#  'Refosco',
#  'Rhone-Style Red Blend',
#  'Rhone-Style White Blend',
#  'Ribolla Gialla',
#  'Rieslaner',
#  'Riesling',
#  'Rivaner',
#  'Rkatsiteli',
#  'Robola',
#  'Roditis',
#  'Rolle',
#  'Rose',
#  'Roter Veltliner',
#  'Rotgipfler',
#  'Roussanne',
#  'Ruche',
#  'Sagrantino',
#  'Samling',
#  'Sangiovese',
#  'Saperavi',
#  'Sauvignon Blanc',
#  'Sauvignon Gris',
#  'Savagnin',
#  'Savatiano',
#  'Scheurebe',
#  'Schiava',
#  'Semillon',
#  'Seyval Blanc',
#  'Sherry',
#  'Siria',
#  'Sousao',
#  'Sparkling Blend',
#  'Spatburgunder',
#  'St. Laurent',
#  'Susumaniello',
#  'Sylvaner',
#  'Silvaner',
#  'Symphony',
#  'Syrah',
#  'Shiraz',
#  'Tannat',
#  'Tempranillo',
#  'Tempranillo Blanco',
#  'Teran',
#  'Teroldego',
#  'Tinta de Toro',
#  'Tinta Fina',
#  'Tinto Fino',
#  'Tinta Roriz',
#  'Tinto del Pais',
#  'Tokaji',
#  'Tokay',
#  'Torrontes',
#  'Touriga Franca',
#  'Touriga Nacional',
#  'Traminer',
#  'Traminette',
#  'Trebbiano',
#  'Trepat',
#  'Trincadeira',
#  'Trousseau',
#  'Turbiana',
#  'Uva di Troia',
#  'Valdiguie',
#  'Verdeca',
#  'Verdejo',
#  'Verdelho',
#  'Verdicchio',
#  'Verduzzo Friulano',
#  'Verduzzo',
#  'Vermentino',
#  'Vernaccia',
#  'Vidal Blanc',
#  'Vignoles',
#  'Vilana',
#  'Viognier',
#  'Viura',
#  'Vranec',
#  'Weissburgunder',
#  'Welschriesling',
#  'White Blend',
#  'Xarel-lo',
#  'Xinomavro',
#  'Zibibbo',
#  'Zierfandler',
#  'Zinfandel',
#  'Zweigelt']

# %%
# Now we have a useful list of grapes that we check against the names column, and fill in the grapes 
# column with any matches. Normally, I wouldn't just run over the entire 'grape' column with new values
# without checking for existing values first, or I would apply the find_grape function here into a new
# column. However, since we already know the 'grape' column is null, we are free to proceed here with a
# more simple function.

def find_grape(name):
    for grape in grape_list:
        if grape in name:
            return grape
    return None

df['grape'] = df['name'].apply(find_grape)

df.head(20)
# Out:
#                                         name               grape  \
# 0   Laurenz V Charming Gruner Veltliner 2013    Gruner Veltliner
# 1   Laurenz V Charming Gruner Veltliner 2014    Gruner Veltliner
# 2    Laurenz V Singing Gruner Veltliner 2007    Gruner Veltliner
# 3    Laurenz V Singing Gruner Veltliner 2010    Gruner Veltliner
# 4    Laurenz V Singing Gruner Veltliner 2011    Gruner Veltliner
# 5    Laurenz V Singing Gruner Veltliner 2013    Gruner Veltliner
# 6                Lava Cap American River Red                None
# 7                      Lava Cap Barbera 2010             Barbera
# 8         Lava Cap Battonage Chardonnay 2012          Chardonnay
# 9           Lava Cap Cabernet Sauvignon 2013  Cabernet Sauvignon
# 10          Lava Cap Cabernet Sauvignon 2016  Cabernet Sauvignon
# 11                Lava Cap Petite Sirah 2013        Petite Sirah
# 12                Lava Cap Petite Sirah 2014        Petite Sirah
# 13                Lava Cap Petite Sirah 2016        Petite Sirah
# 14          Lava Cap Reserve Chardonnay 2015          Chardonnay
# 15          Lava Cap Reserve Chardonnay 2018          Chardonnay
# 16          Lava Cap Reserve Chardonnay 2016          Chardonnay
# 17              Lava Cap Reserve Merlot 2015              Merlot
# 18             Lava Cap Sauvignon Blanc 2015     Sauvignon Blanc
# 19             Lava Cap Sauvignon Blanc 2017     Sauvignon Blanc
#
#                                      region styles  rating  \
# 0                          Kamptal, Austria  white    90.0
# 1                          Kamptal, Austria  white    90.0
# 2                                   Austria  white    90.0
# 3                                   Austria  white    88.0
# 4                                   Austria  white    88.0
# 5                                   Austria  white    89.0
# 6   El Dorado, Sierra Foothills, California    red    90.0
# 7              Sierra Foothills, California    red    90.0
# 8              Sierra Foothills, California  white    91.0
# 9   El Dorado, Sierra Foothills, California    red    90.0
# 10  El Dorado, Sierra Foothills, California    red    93.0
# 11  El Dorado, Sierra Foothills, California    red    90.0
# 12  El Dorado, Sierra Foothills, California    red    92.0
# 13  El Dorado, Sierra Foothills, California    red    92.0
# 14  El Dorado, Sierra Foothills, California  white    92.0
# 15  El Dorado, Sierra Foothills, California  white    92.0
# 16  El Dorado, Sierra Foothills, California  white    92.0
# 17  El Dorado, Sierra Foothills, California    red    90.0
# 18  El Dorado, Sierra Foothills, California  white    90.0
# 19  El Dorado, Sierra Foothills, California  white    89.0
#
#                                                 notes
# 0   Aromas of ripe apples and a typical Veltliner ...
# 1   Aromas of ripe apples and a typical Veltliner ...
# 2   A very attractive fruit bouquet yields apple, ...
# 3   A very attractive fruit bouquet yields apple, ...
# 4   A very attractive fruit bouquet yields apple, ...
# 5   A very attractive fruit bouquet yields apple, ...
# 6   This wine was created as a table wine. We want...
# 7   The plump, rich cherry, raspberry and plum fru...
# 8   This perfectly balanced wine begins with invit...
# 9   Lava Cap’s estate grown Cabernet Sauvignon gra...
# 10  Lava Cap’s estate grown grapes have long been ...
# 11  Lava Cap's 2013 Petite Sirah is a BIG one for ...
# 12  On the nose, the 2014 Petite Sirah has notes o...
# 13  The 2016 Petite Sirah has notes of elegant wil...
# 14  Zesty lemon and apple blossom aroma lead into ...
# 15  The 2018 vintage continues to consistently ele...
# 16  Zesty lemon and apple blossom aroma lead into ...
# 17  Pleasant forest greenery and plum scents highl...
# 18  An expressive aromatic wine displays note soft...
# 19  After the grapes are crushed, they are 100% fe...

# %%
# This function will return every entry in the dataframe with a null entry. 

def nans(df): return df[df.isnull().any(axis=1)]
null_grapes = nans(df)
null_grapes
# Out:
#                                               name               grape  \
# 6                      Lava Cap American River Red                None
# 27                  Lavau Chateauneuf-du-Pape 2016                None
# 28                  Lavau Chateauneuf-du-Pape 2014                None
# 29                  Lavau Chateauneuf-du-Pape 2015                None
# 30                             Lavau Gigondas 2013                None
# ..                                             ...                 ...
# 717            Lewis Cellars Alec's Blend Red 2017                None
# 732                     Lewis Cellars Cuvee L 2005                None
# 733                     Lewis Cellars Cuvee L 2006                None
# 758  Lewis Cellars Reserve Cabernet Sauvignon 2010  Cabernet Sauvignon
# 778                        Lexington Apex Red 2011                None
#
#                                       region styles  rating  \
# 6    El Dorado, Sierra Foothills, California    red    90.0
# 27        Chateauneuf-du-Pape, Rhone, France    red    92.0
# 28        Chateauneuf-du-Pape, Rhone, France    red    91.0
# 29        Chateauneuf-du-Pape, Rhone, France    red    91.0
# 30                   Gigondas, Rhone, France    red    91.0
# ..                                       ...    ...     ...
# 717                  Napa Valley, California    red    92.0
# 732                  Napa Valley, California    red    95.0
# 733                  Napa Valley, California    red    93.0
# 758                  Napa Valley, California    red    96.0
# 778         Santa Cruz Mountains, California    red    91.0
#
#                                                  notes
# 6    This wine was created as a table wine. We want...
# 27   Complex nose of plums and black cherries with ...
# 28   Complex nose of plums and black cherries with ...
# 29   Complex nose of plums and black cherries with ...
# 30   The natural exposure of this vineyard delivers...
# ..                                                 ...
# 717  Complex and fruit-forward with opulent black c...
# 732  Think of Cuvee L as super-charged Lewis Reserv...
# 733  First created from the spectacular 1997 vintag...
# 758                                                NaN
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot
#
# [334 rows x 6 columns]
